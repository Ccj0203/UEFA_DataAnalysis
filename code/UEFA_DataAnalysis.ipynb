# %%
import pandas as pd
import json
import requests
from tqdm import *
import time

headers = {
    'Accept':'application/json, text/plain, */*',
    'Accept-Encoding':'gzip, deflate, br, zstd',
    'Accept-Language':'zh-CN,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    # If-None-Match:"06c0f14de3c0229b8ad093f25a17f6572"
    # Origin:https://www.uefa.com
    # Priority:u=1, i
    # Referer:https://www.uefa.com/
    # Sec-Ch-Ua:"Not/A)Brand";v="8", "Chromium";v="126", "Microsoft Edge";v="126"
    # Sec-Ch-Ua-Mobile:?0
    # Sec-Ch-Ua-Platform:"Windows"
    # Sec-Fetch-Dest:empty
    # Sec-Fetch-Mode:cors
    # Sec-Fetch-Site:same-site
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0'
    # X-Api-Key:ceeee1a5bb209502c6c438abd8f30aef179ce669bb9288f2d1cf2fa276de03f4
}

# %%
def get_matches_info():
    url = "https://match.uefa.com/v5/matches?competitionId=3&fromDate=2024-06-15&limit=55&offset=0&order=ASC&phase=ALL&seasonYear=2024&toDate=2024-07-15&utcOffset=8"
    
    res = requests.get(url,headers=headers)

    data = json.loads(res.text)
    
    return [i['id'] for i in data]

match_ids = get_matches_info()
match_ids

# %%
len(match_ids)
# Out:
# 51

# %%
data
# Out:
# [{'awayTeam': {'associationId': '200117',
#    'associationLogoUrl': 'https://img.uefa.com/imgml/uefacom/elements/logos/ma/SCO.svg',
#    'bigLogoUrl': 'https://img.uefa.com/imgml/flags/700x700/SCO.png',
#    'confederationType': 'UEFA',
#    'countryCode': 'SCO',
#    'id': '117',
#    'idProvider': 'FAME',
#    'internationalName': 'Scotland',
#    'isPlaceHolder': False,
#    'logoUrl': 'https://img.uefa.com/imgml/flags/70x70/SCO.png',
#    'mediumLogoUrl': 'https://img.uefa.com/imgml/flags/240x240/SCO.png',
#    'organizationId': '200117',
#    'teamCode': 'SCO',
#    'teamTypeDetail': 'NATIONAL_MEN_TEAM_A',
#    'translations': {'countryName': {'EN': 'Scotland',
#      'FR': 'Écosse',
#      'DE': 'Schottland',
#      'ES': 'Escocia',
#      'PT': 'Escócia',
#      'IT': 'Scozia',
#      'RU': 'Шотландия',
#      'ZH': '苏格兰',
#      'TR': 'Scotland',
#      'HU': 'Scotland',
#      'CS': 'Scotland',
#      'NL': 'Scotland'},
#     'displayName': {'EN': 'Scotland',
#      'FR': 'Écosse',
#      'DE': 'Schottland',
#      'ES': 'Escocia',
#      'PT': 'Escócia',
#      'IT': 'Scozia',
#      'RU': 'Шотландия',
#      'ZH': '苏格兰',
#      'TR': 'Scotland',
#      'HU': 'Scotland',
#      'CS': 'Scotland',
#      'NL': 'Scotland'},
#     'displayOfficialName': {'EN': 'Scotland',
#      'FR': 'Écosse',
#      'DE': 'Schottland',
#      'ES': 'Escocia',
#      'PT': 'Escócia',
#      'IT': 'Scozia',
#      'RU': 'Шотландия',
#      'ZH': '苏格兰',
#      'TR': 'Scotland',
#      'HU': 'Scotland',
#      'CS': 'Scotland',
#      'NL': 'Scotland'},
#     'displayTeamCode': {'EN': 'SCO',
#      'FR': 'SCO',
#      'DE': 'SCO',
#      'ES': 'SCO',
#      'PT': 'SCO',
#      'IT': 'SCO',
#      'RU': 'SCO',
#      'ZH': 'SCO',
#      'TR': 'SCO',
#      'HU': 'SCO',
#      'CS': 'SCO',
#      'NL': 'SCO'}},
#    'typeIsNational': True,
#    'typeTeam': 'NATIONAL'},
#   'behindClosedDoors': False,
#   'competition': {'age': 'ADULT',
#    'code': 'EURO',
#    'id': '3',
#    'images': {'FULL_LOGO': 'https://img.uefa.com/imgml/uefacom/elements/logos/competitions/color/full/3.svg'},
#    'metaData': {'name': 'European Championship'},
#    'region': 'CONTINENTAL',
#    'sex': 'MALE',
#    'sportsType': 'FOOTBALL',
#    'teamCategory': 'NATIONAL',
#    'translations': {'name': {'EN': 'UEFA EURO',
#      'FR': 'UEFA EURO',
#      'DE': 'UEFA EURO',
#      'ES': 'UEFA EURO',
#      'PT': 'UEFA EURO',
#      'IT': 'UEFA EURO',
#      'RU': 'ЕВРО',
#      'ZH': 'UEFA EURO',
#      'TR': 'UEFA EURO',
#      'HU': 'UEFA EURO',
#      'CS': 'UEFA EURO',
#      'NL': 'UEFA EURO'},
#     'prequalifyingName': {'EN': 'UEFA EURO',
#      'FR': 'UEFA EURO',
#      'DE': 'UEFA EURO',
#      'ES': 'UEFA EURO',
#      'PT': 'UEFA EURO',
#      'IT': 'UEFA EURO',
#      'RU': 'ЕВРО',
#      'ZH': 'UEFA EURO',
#      'TR': 'UEFA EURO',
#      'HU': 'UEFA EURO',
#      'CS': 'UEFA EURO',
#      'NL': 'UEFA EURO'},
#     'qualifyingName': {'EN': 'European Qualifiers',
#      'FR': 'Éliminatoires européens',
#      'DE': 'European Qualifiers',
#      'ES': 'Clasificatorios Europeos',
#      'PT': 'Qualificação Europeia',
#      'IT': 'Qualificazioni Europee',
#      'RU': 'Европейская квалификация',
#      'ZH': 'EURO Qualifiers',
#      'TR': 'European Qualifiers',
#      'HU': 'European Qualifiers',
#      'CS': 'European Qualifiers',
#      'NL': 'European Qualifiers'},
#     'tournamentName': {'EN': 'UEFA EURO',
#      'FR': 'UEFA EURO',
#      'DE': 'UEFA EURO',
#      'ES': 'UEFA EURO',
#      'PT': 'UEFA EURO',
#      'IT': 'UEFA EURO',
#      'RU': 'ЕВРО',
#      'ZH': 'UEFA EURO',
#      'TR': 'UEFA EURO',
#      'HU': 'UEFA EURO',
#      'CS': 'UEFA EURO',
#      'NL': 'UEFA EURO'}},
#    'type': 'CUP'},
#   'fullTimeAt': '2024-06-14T20:55:36.005Z',
#   'group': {'competitionId': '3',
#    'id': '2006644',
#    'metaData': {'groupName': 'Group A', 'groupShortName': 'GrpA'},
#    'order': 1,
#    'phase': 'TOURNAMENT',
#    'roundId': '2001079',
#    'seasonYear': '2024',
#    'teams': ['57', '47', '117', '128'],
#    'teamsQualifiedNumber': 2,
#    'translations': {'name': {'EN': 'Group A',
#      'FR': 'Groupe A',
#      'DE': 'Gruppe A',
#      'ES': 'Grupo A',
#      'PT': 'Grupo A',
#      'IT': 'Gruppo A',
#      'RU': 'Группа A',
#      'ZH': 'A组',
#      'TR': 'Group A',
#      'HU': 'A Csoport',
#      'CS': 'Group A',
#      'NL': 'Groep A'},
#     'shortName': {'EN': 'A',
#      'FR': 'A',
#      'DE': 'A',
#      'ES': 'A',
#      'PT': 'A',
#      'IT': 'A',
#      'RU': 'A',
#      'ZH': 'A',
#      'TR': 'A',
#      'HU': 'A',
#      'CS': 'A',
#      'NL': 'A'}},
#    'type': 'STANDARD'},
#   'homeTeam': {'associationId': '200047',
#    'associationLogoUrl': 'https://img.uefa.com/imgml/uefacom/elements/logos/ma/GER.svg',
#    'bigLogoUrl': 'https://img.uefa.com/imgml/flags/700x700/GER.png',
#    'confederationType': 'UEFA',
#    'countryCode': 'GER',
#    'id': '47',
#    'idProvider': 'FAME',
#    'internationalName': 'Germany',
#    'isPlaceHolder': False,
#    'logoUrl': 'https://img.uefa.com/imgml/flags/70x70/GER.png',
#    'mediumLogoUrl': 'https://img.uefa.com/imgml/flags/240x240/GER.png',
#    'organizationId': '200047',
#    'teamCode': 'GER',
#    'teamTypeDetail': 'NATIONAL_MEN_TEAM_A',
#    'translations': {'countryName': {'EN': 'Germany',
#      'FR': 'Allemagne',
#      'DE': 'Deutschland',
#      'ES': 'Alemania',
#      'PT': 'Alemanha',
#      'IT': 'Germania',
#      'RU': 'Германия',
#      'ZH': '德国',
#      'TR': 'Germany',
#      'HU': 'Germany',
#      'CS': 'Germany',
#      'NL': 'Germany'},
#     'displayName': {'EN': 'Germany',
#      'FR': 'Allemagne',
#      'DE': 'Deutschland',
#      'ES': 'Alemania',
#      'PT': 'Alemanha',
#      'IT': 'Germania',
#      'RU': 'Германия',
#      'ZH': '德国',
#      'TR': 'Germany',
#      'HU': 'Germany',
#      'CS': 'Germany',
#      'NL': 'Germany'},
#     'displayOfficialName': {'EN': 'Germany',
#      'FR': 'Allemagne',
#      'DE': 'Deutschland',
#      'ES': 'Alemania',
#      'PT': 'Alemanha',
#      'IT': 'Germania',
#      'RU': 'Германия',
#      'ZH': '德国',
#      'TR': 'Germany',
#      'HU': 'Germany',
#      'CS': 'Germany',
#      'NL': 'Germany'},
#     'displayTeamCode': {'EN': 'GER',
#      'FR': 'GER',
#      'DE': 'GER',
#      'ES': 'GER',
#      'PT': 'GER',
#      'IT': 'GER',
#      'RU': 'GER',
#      'ZH': 'GER',
#      'TR': 'GER',
#      'HU': 'GER',
#      'CS': 'GER',
#      'NL': 'GER'}},
#    'typeIsNational': True,
#    'typeTeam': 'NATIONAL'},
#   'id': '2036161',
#   'kickOffTime': {'date': '2024-06-15',
#    'dateTime': '2024-06-14T19:00:00Z',
#    'utcOffsetInHours': 2},
#   'lineupStatus': 'TACTICAL_AVAILABLE',
#   'matchAttendance': 65052,
#   'matchNumber': 1,
#   'matchday': {'competitionId': '3',
#    'dateFrom': '2024-06-13T22:00:00+0000',
#    'dateTo': '2024-06-18T21:59:59+0000',
#    'format': 'REGULAR',
#    'id': '33779',
#    'longName': 'Matchday 1',
#    'name': 'MD1',
#    'roundId': '2001079',
#    'seasonYear': '2024',
#    'sequenceNumber': '1',
#    'translations': {'longName': {'EN': 'Matchday 1',
#      'FR': 'Journée 1',
#      'DE': 'Spieltag 1',
#      'ES': 'Jornada 1',
#      'PT': 'Jornada 1',
#      'IT': 'Giornata 1',
#      'RU': 'Тур 1',
#      'ZH': '比赛日 1',
#      'TR': 'Matchday 1',
#      'HU': 'Matchday 1',
#      'CS': 'Matchday 1',
#      'NL': 'Matchday 1'},
#     'name': {'EN': 'MD 1',
#      'FR': 'J 1',
#      'DE': 'ST 1',
#      'ES': 'JOR 1',
#      'PT': 'J 1',
#      'IT': 'G 1',
#      'RU': 'Тур 1',
#      'ZH': '比赛日 1',
#      'TR': 'MD 1',
#      'HU': 'MD 1',
#      'CS': 'MD 1',
#      'NL': 'MD 1'}},
#    'type': 'MATCHDAY'},
#   'playerEvents': {'redCards': [{'id': '9ef72ac9-0ac6-47a9-b4c6-742dbda4dcbb',
#      'images': {'PLAYER_CELEBRATING': 'https://img.uefa.com/imgml/TP/players/3/2024/900x1350/250107074.webp'},
#      'phase': 'FIRST_HALF',
#      'player': {'age': '25',
#       'birthDate': '1999-03-25',
#       'clubId': '52744',
#       'clubJerseyNumber': '5',
#       'clubShirtName': 'Porteous',
#       'countryCode': 'SCO',
#       'fieldPosition': 'DEFENDER',
#       'gender': 'MALE',
#       'id': '250107074',
#       'imageUrl': 'https://img.uefa.com/imgml/TP/players/3/2024/324x324/250107074.jpg',
#       'internationalName': 'Ryan Porteous',
#       'nationalFieldPosition': 'DEFENDER',
#       'nationalJerseyNumber': '15',
#       'nationalShirtName': 'Porteous',
#       'nationalTeamId': '117',
#       'translations': {'countryName': {'EN': 'Scotland',
#         'FR': 'Écosse',
#         'DE': 'Schottland',
#         'ES': 'Escocia',
#         'PT': 'Escócia',
#         'IT': 'Scozia',
#         'RU': 'Шотландия',
#         'ZH': '苏格兰',
#         'TR': 'Scotland',
#         'HU': 'Scotland',
#         'CS': 'Scotland',
#         'NL': 'Scotland'},
#        'fieldPosition': {'EN': 'Defender',
#         'FR': 'Défenseur',
#         'DE': 'Verteidiger',
#         'ES': 'Defensa',
#         'PT': 'Defesa',
#         'IT': 'Difensore',
#         'RU': 'Защитник',
#         'ZH': '后卫',
#         'TR': 'Defender',
#         'HU': 'Defender',
#         'CS': 'Defender',
#         'NL': 'Defender'},
#        'firstName': {'EN': 'Ryan',
#         'FR': 'Ryan',
#         'DE': 'Ryan',
#         'ES': 'Ryan',
#         'PT': 'Ryan',
#         'IT': 'Ryan',
#         'RU': 'Райан',
#         'ZH': '瑞安',
#         'TR': 'Ryan',
#         'HU': 'Ryan',
#         'CS': 'Ryan',
#         'NL': 'Ryan'},
#        'lastName': {'EN': 'Porteous',
#         'FR': 'Porteous',
#         'DE': 'Porteous',
#         'ES': 'Porteous',
#         'PT': 'Porteous',
#         'IT': 'Porteous',
#         'RU': 'Портеус',
#         'ZH': '波蒂厄斯',
#         'TR': 'Porteous',
#         'HU': 'Porteous',
#         'CS': 'Porteous',
#         'NL': 'Porteous'},
#        'name': {'EN': 'Ryan Porteous',
#         'FR': 'Ryan Porteous',
#         'DE': 'Ryan Porteous',
#         'ES': 'Ryan Porteous',
#         'PT': 'Ryan Porteous',
#         'IT': 'Ryan Porteous',
#         'RU': 'Райан Портеус',
#         'ZH': '瑞安·波蒂厄斯',
#         'TR': 'Ryan Porteous',
#         'HU': 'Ryan Porteous',
#         'CS': 'Ryan Porteous',
#         'NL': 'Ryan Porteous'},
#        'nationalFieldPosition': {'EN': 'Defender',
#         'FR': 'Défenseur',
#         'DE': 'Verteidiger',
#         'ES': 'Defensa',
#         'PT': 'Defesa',
#         'IT': 'Difensore',
#         'RU': 'Защитник',
#         'ZH': '后卫',
#         'TR': 'Defender',
#         'HU': 'Defender',
#         'CS': 'Defender',
#         'NL': 'Defender'},
#        'shortName': {'EN': 'Porteous',
#         'FR': 'Porteous',
#         'DE': 'Porteous',
#         'ES': 'Porteous',
#         'PT': 'Porteous',
#         'IT': 'Porteous',
#         'RU': 'Портеус',
#         'ZH': '波蒂厄斯',
#         'TR': 'Porteous',
#         'HU': 'Porteous',
#         'CS': 'Porteous',
#         'NL': 'Porteous'}}},
#      'teamId': '117',
#      'teamIdProvider': 'FAME',
#      'time': {'minute': 44, 'second': 55}}],
#    'scorers': [{'goalType': 'SCORED',
#      'id': 'fff88dcd-5535-4692-bd42-5829047795c7',
#      'images': {'PLAYER_CELEBRATING': 'https://img.uefa.com/imgml/TP/players/3/2024/900x1350/250139445.webp'},
#      'phase': 'FIRST_HALF',
#      'player': {'age': '21',
#       'birthDate': '2003-05-03',
#       'clubId': '50109',
#       'clubJerseyNumber': '10',
#       'clubShirtName': 'Wirtz',
#       'countryCode': 'GER',
#       'countryOfBirthCode': 'GER',
#       'detailedFieldPosition': 'WINGER',
#       'fieldPosition': 'MIDFIELDER',
#       'gender': 'MALE',
#       'id': '250139445',
#       'imageUrl': 'https://img.uefa.com/imgml/TP/players/3/2024/324x324/250139445.jpg',
#       'internationalName': 'Florian Wirtz',
#       'nationalFieldPosition': 'MIDFIELDER',
#       'nationalJerseyNumber': '17',
#       'nationalShirtName': 'Wirtz',
#       'nationalTeamId': '47',
#       'translations': {'countryName': {'EN': 'Germany',
#         'FR': 'Allemagne',
#         'DE': 'Deutschland',
#         'ES': 'Alemania',
#         'PT': 'Alemanha',
#         'IT': 'Germania',
#         'RU': 'Германия',
#         'ZH': '德国',
#         'TR': 'Germany',
#         'HU': 'Germany',
#         'CS': 'Germany',
#         'NL': 'Germany'},
#        'countryOfBirthName': {'EN': 'Germany',
#         'FR': 'Allemagne',
#         'DE': 'Deutschland',
#         'ES': 'Alemania',
#         'PT': 'Alemanha',
#         'IT': 'Germania',
#         'RU': 'Германия',
#         'ZH': '德国',
#         'TR': 'Germany',
#         'HU': 'Germany',
#         'CS': 'Germany',
#         'NL': 'Germany'},
#        'fieldPosition': {'EN': 'Midfielder',
#         'FR': 'Milieu',
#         'DE': 'Mittelfeldspieler',
#         'ES': 'Centrocampista',
#         'PT': 'Médio',
#         'IT': 'Centrocampista',
#         'RU': 'Полузащитник',
#         'ZH': '中场球员',
#         'TR': 'Midfielder',
#         'HU': 'Midfielder',
#         'CS': 'Midfielder',
#         'NL': 'Midfielder'},
#        'firstName': {'EN': 'Florian',
#         'FR': 'Florian',
#         'DE': 'Florian',
#         'ES': 'Florian',
#         'PT': 'Florian',
#         'IT': 'Florian',
#         'RU': 'Флориан',
#         'ZH': '弗洛里安',
#         'TR': 'Florian',
#         'HU': 'Florian',
#         'CS': 'Florian',
#         'NL': 'Florian'},
#        'lastName': {'EN': 'Wirtz',
#         'FR': 'Wirtz',
#         'DE': 'Wirtz',
#         'ES': 'Wirtz',
#         'PT': 'Wirtz',
#         'IT': 'Wirtz',
#         'RU': 'Вирц',
#         'ZH': '维尔茨',
#         'TR': 'Wirtz',
#         'HU': 'Wirtz',
#         'CS': 'Wirtz',
#         'NL': 'Wirtz'},
#        'name': {'EN': 'Florian Wirtz',
#         'FR': 'Florian Wirtz',
#         'DE': 'Florian Wirtz',
#         'ES': 'Florian Wirtz',
#         'PT': 'Florian Wirtz',
#         'IT': 'Florian Wirtz',
#         'RU': 'Флориан Вирц',
#         'ZH': '弗洛里安·维尔茨',
#         'TR': 'Florian Wirtz',
#         'HU': 'Florian Wirtz',
#         'CS': 'Florian Wirtz',
#         'NL': 'Florian Wirtz'},
#        'nationalFieldPosition': {'EN': 'Midfielder',
#         'FR': 'Milieu',
#         'DE': 'Mittelfeldspieler',
#         'ES': 'Centrocampista',
#         'PT': 'Médio',
#         'IT': 'Centrocampista',
#         'RU': 'Полузащитник',
#         'ZH': '中场球员',
#         'TR': 'Midfielder',
#         'HU': 'Midfielder',
#         'CS': 'Midfielder',
#         'NL': 'Midfielder'},
#        'shortName': {'EN': 'Wirtz',
#         'FR': 'Wirtz',
#         'DE': 'Wirtz',
#         'ES': 'Wirtz',
#         'PT': 'Wirtz',
#         'IT': 'Wirtz',
#         'RU': 'Вирц',
#         'ZH': '维尔茨',
#         'TR': 'Wirtz',
#         'HU': 'Wirtz',
#         'CS': 'Wirtz',
#         'NL': 'Wirtz'}}},
#      'teamId': '47',
#      'teamIdProvider': 'FAME',
#      'time': {'minute': 10, 'second': 55}},
#     {'goalType': 'SCORED',
#      'id': 'f9a6a49c-9fc9-4528-bc58-f2e558d10c4a',
#      'images': {'PLAYER_CELEBRATING': 'https://img.uefa.com/imgml/TP/players/3/2024/900x1350/250124430.webp'},
#      'phase': 'FIRST_HALF',
#      'player': {'age': '21',
#       'birthDate': '2003-02-26',
#       'clubId': '50037',
#       'clubJerseyNumber': '42',
#       'clubShirtName': 'Musiala',
#       'countryCode': 'GER',
#       'countryOfBirthCode': 'GER',
#       'detailedFieldPosition': 'UNKNOWN',
#       'fieldPosition': 'MIDFIELDER',
#       'gender': 'MALE',
#       'id': '250124430',
#       'imageUrl': 'https://img.uefa.com/imgml/TP/players/3/2024/324x324/250124430.jpg',
#       'internationalName': 'Jamal Musiala',
#       'nationalFieldPosition': 'MIDFIELDER',
#       'nationalJerseyNumber': '10',
#       'nationalShirtName': 'Musiala',
#       'nationalTeamId': '47',
#       'translations': {'countryName': {'EN': 'Germany',
#         'FR': 'Allemagne',
#         'DE': 'Deutschland',
#         'ES': 'Alemania',
#         'PT': 'Alemanha',
#         'IT': 'Germania',
#         'RU': 'Германия',
#         'ZH': '德国',
#         'TR': 'Germany',
#         'HU': 'Germany',
#         'CS': 'Germany',
#         'NL': 'Germany'},
#        'countryOfBirthName': {'EN': 'Germany',
#         'FR': 'Allemagne',
#         'DE': 'Deutschland',
#         'ES': 'Alemania',
#         'PT': 'Alemanha',
#         'IT': 'Germania',
#         'RU': 'Германия',
#         'ZH': '德国',
#         'TR': 'Germany',
#         'HU': 'Germany',
#         'CS': 'Germany',
#         'NL': 'Germany'},
#        'fieldPosition': {'EN': 'Midfielder',
#         'FR': 'Milieu',
#         'DE': 'Mittelfeldspieler',
#         'ES': 'Centrocampista',
#         'PT': 'Médio',
#         'IT': 'Centrocampista',
#         'RU': 'Полузащитник',
#         'ZH': '中场球员',
#         'TR': 'Midfielder',
#         'HU': 'Midfielder',
#         'CS': 'Midfielder',
#         'NL': 'Midfielder'},
#        'firstName': {'EN': 'Jamal',
#         'FR': 'Jamal',
#         'DE': 'Jamal',
#         'ES': 'Jamal',
#         'PT': 'Jamal',
#         'IT': 'Jamal',
#         'RU': 'Джамал',
#         'ZH': '贾马尔',
#         'TR': 'Jamal',
#         'HU': 'Jamal',
#         'CS': 'Jamal',
#         'NL': 'Jamal'},
#        'lastName': {'EN': 'Musiala',
#         'FR': 'Musiala',
#         'DE': 'Musiala',
#         'ES': 'Musiala',
#         'PT': 'Musiala',
#         'IT': 'Musiala',
#         'RU': 'Мусиала',
#         'ZH': '穆夏拉',
#         'TR': 'Musiala',
#         'HU': 'Musiala',
#         'CS': 'Musiala',
#         'NL': 'Musiala'},
#        'name': {'EN': 'Jamal Musiala',
#         'FR': 'Jamal Musiala',
#         'DE': 'Jamal Musiala',
#         'ES': 'Jamal Musiala',
#         'PT': 'Jamal Musiala',
#         'IT': 'Jamal Musiala',
#         'RU': 'Джамал Мусиала',
#         'ZH': '贾马尔·穆夏拉',
#         'TR': 'Jamal Musiala',
#         'HU': 'Jamal Musiala',
#         'CS': 'Jamal Musiala',
#         'NL': 'Jamal Musiala'},
#        'nationalFieldPosition': {'EN': 'Midfielder',
#         'FR': 'Milieu',
#         'DE': 'Mittelfeldspieler',
#         'ES': 'Centrocampista',
#         'PT': 'Médio',
#         'IT': 'Centrocampista',
#         'RU': 'Полузащитник',
#         'ZH': '中场球员',
#         'TR': 'Midfielder',
#         'HU': 'Midfielder',
#         'CS': 'Midfielder',
#         'NL': 'Midfielder'},
#        'shortName': {'EN': 'Musiala',
#         'FR': 'Musiala',
#         'DE': 'Musiala',
#         'ES': 'Musiala',
#         'PT': 'Musiala',
#         'IT': 'Musiala',
#         'RU': 'Мусиала',
#         'ZH': '穆夏拉',
#         'TR': 'Musiala',
#         'HU': 'Musiala',
#         'CS': 'Musiala',
#         'NL': 'Musiala'}}},
#      'teamId': '47',
#      'teamIdProvider': 'FAME',
#      'time': {'minute': 19, 'second': 43}},
#     {'goalType': 'PENALTY',
#      'id': '6f0c0e5f-f5a6-4fa8-82eb-7606f2e465c8',
#      'images': {'PLAYER_CELEBRATING': 'https://img.uefa.com/imgml/TP/players/3/2024/900x1350/250087938.webp'},
#      'phase': 'FIRST_HALF',
#      'player': {'age': '25',
#       'birthDate': '1999-06-11',
#       'clubId': '52280',
#       'clubJerseyNumber': '29',
#       'clubShirtName': 'Havertz',
#       'countryCode': 'GER',
#       'detailedFieldPosition': 'STRIKER',
#       'fieldPosition': 'MIDFIELDER',
#       'gender': 'MALE',
#       'id': '250087938',
#       'imageUrl': 'https://img.uefa.com/imgml/TP/players/3/2024/324x324/250087938.jpg',
#       'internationalName': 'Kai Havertz',
#       'nationalFieldPosition': 'FORWARD',
#       'nationalJerseyNumber': '7',
#       'nationalShirtName': 'Havertz',
#       'nationalTeamId': '47',
#       'translations': {'countryName': {'EN': 'Germany',
#         'FR': 'Allemagne',
#         'DE': 'Deutschland',
#         'ES': 'Alemania',
#         'PT': 'Alemanha',
#         'IT': 'Germania',
#         'RU': 'Германия',
#         'ZH': '德国',
#         'TR': 'Germany',
#         'HU': 'Germany',
#         'CS': 'Germany',
#         'NL': 'Germany'},
#        'fieldPosition': {'EN': 'Midfielder',
#         'FR': 'Milieu',
#         'DE': 'Mittelfeldspieler',
#         'ES': 'Centrocampista',
#         'PT': 'Médio',
#         'IT': 'Centrocampista',
#         'RU': 'Полузащитник',
#         'ZH': '中场球员',
#         'TR': 'Midfielder',
#         'HU': 'Midfielder',
#         'CS': 'Midfielder',
#         'NL': 'Midfielder'},
#        'firstName': {'EN': 'Kai',
#         'FR': 'Kai',
#         'DE': 'Kai',
#         'ES': 'Kai',
#         'PT': 'Kai',
#         'IT': 'Kai',
#         'RU': 'Кай',
#         'ZH': '凯',
#         'TR': 'Kai',
#         'HU': 'Kai',
#         'CS': 'Kai',
#         'NL': 'Kai'},
#        'lastName': {'EN': 'Havertz',
#         'FR': 'Havertz',
#         'DE': 'Havertz',
#         'ES': 'Havertz',
#         'PT': 'Havertz',
#         'IT': 'Havertz',
#         'RU': 'Хаверц',
#         'ZH': '哈弗茨',
#         'TR': 'Havertz',
#         'HU': 'Havertz',
#         'CS': 'Havertz',
#         'NL': 'Havertz'},
#        'name': {'EN': 'Kai Havertz',
#         'FR': 'Kai Havertz',
#         'DE': 'Kai Havertz',
#         'ES': 'Kai Havertz',
#         'PT': 'Kai Havertz',
#         'IT': 'Kai Havertz',
#         'RU': 'Кай Хаверц',
#         'ZH': '凯·哈弗茨',
#         'TR': 'Kai Havertz',
#         'HU': 'Kai Havertz',
#         'CS': 'Kai Havertz',
#         'NL': 'Kai Havertz'},
#        'nationalFieldPosition': {'EN': 'Forward',
#         'FR': 'Attaquant',
#         'DE': 'Stürmer',
#         'ES': 'Delantero',
#         'PT': 'Avançado',
#         'IT': 'Attaccante',
#         'RU': 'Нападающий',
#         'ZH': '前锋',
#         'TR': 'Forward',
#         'HU': 'Forward',
#         'CS': 'Forward',
#         'NL': 'Forward'},
#        'shortName': {'EN': 'Havertz',
#         'FR': 'Havertz',
#         'DE': 'Havertz',
#         'ES': 'Havertz',
#         'PT': 'Havertz',
#         'IT': 'Havertz',
#         'RU': 'Хаверц',
#         'ZH': '哈弗茨',
#         'TR': 'Havertz',
#         'HU': 'Havertz',
#         'CS': 'Havertz',
#         'NL': 'Havertz'}}},
#      'teamId': '47',
#      'teamIdProvider': 'FAME',
#      'time': {'injuryMinute': 1, 'minute': 45, 'second': 34}},
#     {'goalType': 'SCORED',
#      'id': '4738363d-686a-4e68-877c-a13901edadf3',
#      'images': {'PLAYER_CELEBRATING': 'https://img.uefa.com/imgml/TP/players/3/2024/900x1350/250041844.webp'},
#      'phase': 'SECOND_HALF',
#      'player': {'age': '31',
#       'birthDate': '1993-02-09',
#       'clubId': '52758',
#       'clubJerseyNumber': '14',
#       'clubShirtName': 'Füllkrug',
#       'countryCode': 'GER',
#       'countryOfBirthCode': 'GER',
#       'fieldPosition': 'FORWARD',
#       'gender': 'MALE',
#       'id': '250041844',
#       'imageUrl': 'https://img.uefa.com/imgml/TP/players/3/2024/324x324/250041844.jpg',
#       'internationalName': 'Niclas Füllkrug',
#       'nationalFieldPosition': 'FORWARD',
#       'nationalJerseyNumber': '9',
#       'nationalShirtName': 'Füllkrug',
#       'nationalTeamId': '47',
#       'translations': {'countryName': {'EN': 'Germany',
#         'FR': 'Allemagne',
#         'DE': 'Deutschland',
#         'ES': 'Alemania',
#         'PT': 'Alemanha',
#         'IT': 'Germania',
#         'RU': 'Германия',
#         'ZH': '德国',
#         'TR': 'Germany',
#         'HU': 'Germany',
#         'CS': 'Germany',
#         'NL': 'Germany'},
#        'countryOfBirthName': {'EN': 'Germany',
#         'FR': 'Allemagne',
#         'DE': 'Deutschland',
#         'ES': 'Alemania',
#         'PT': 'Alemanha',
#         'IT': 'Germania',
#         'RU': 'Германия',
#         'ZH': '德国',
#         'TR': 'Germany',
#         'HU': 'Germany',
#         'CS': 'Germany',
#         'NL': 'Germany'},
#        'fieldPosition': {'EN': 'Forward',
#         'FR': 'Attaquant',
#         'DE': 'Stürmer',
#         'ES': 'Delantero',
#         'PT': 'Avançado',
#         'IT': 'Attaccante',
#         'RU': 'Нападающий',
#         'ZH': '前锋',
#         'TR': 'Forward',
#         'HU': 'Forward',
#         'CS': 'Forward',
#         'NL': 'Forward'},
#        'firstName': {'EN': 'Niclas',
#         'FR': 'Niclas',
#         'DE': 'Niclas',
#         'ES': 'Niclas',
#         'PT': 'Niclas',
#         'IT': 'Niclas',
#         'RU': 'Никлас',
#         'ZH': '尼克拉斯',
#         'TR': 'Niclas',
#         'HU': 'Niclas',
#         'CS': 'Niclas',
#         'NL': 'Niclas'},
#        'lastName': {'EN': 'Füllkrug',
#         'FR': 'Füllkrug',
#         'DE': 'Füllkrug',
#         'ES': 'Füllkrug',
#         'PT': 'Füllkrug',
#         'IT': 'Füllkrug',
#         'RU': 'Фюллькруг',
#         'ZH': '菲尔克鲁格',
#         'TR': 'Füllkrug',
#         'HU': 'Füllkrug',
#         'CS': 'Füllkrug',
#         'NL': 'Füllkrug'},
#        'name': {'EN': 'Niclas Füllkrug',
#         'FR': 'Niclas Füllkrug',
#         'DE': 'Niclas Füllkrug',
#         'ES': 'Niclas Füllkrug',
#         'PT': 'Niclas Füllkrug',
#         'IT': 'Niclas Füllkrug',
#         'RU': 'Никлас Фюллькруг',
#         'ZH': '尼克拉斯·菲尔克鲁格',
#         'TR': 'Niclas Füllkrug',
#         'HU': 'Niclas Füllkrug',
#         'CS': 'Niclas Füllkrug',
#         'NL': 'Niclas Füllkrug'},
#        'nationalFieldPosition': {'EN': 'Forward',
#         'FR': 'Attaquant',
#         'DE': 'Stürmer',
#         'ES': 'Delantero',
#         'PT': 'Avançado',
#         'IT': 'Attaccante',
#         'RU': 'Нападающий',
#         'ZH': '前锋',
#         'TR': 'Forward',
#         'HU': 'Forward',
#         'CS': 'Forward',
#         'NL': 'Forward'},
#        'shortName': {'EN': 'Füllkrug',
#         'FR': 'Füllkrug',
#         'DE': 'Füllkrug',
#         'ES': 'Füllkrug',
#         'PT': 'Füllkrug',
#         'IT': 'Füllkrug',
#         'RU': 'Фюллькруг',
#         'ZH': '菲尔克鲁格',
#         'TR': 'Füllkrug',
#         'HU': 'Füllkrug',
#         'CS': 'Füllkrug',
#         'NL': 'Füllkrug'}}},
#      'teamId': '47',
#      'teamIdProvider': 'FAME',
#      'time': {'minute': 68, 'second': 44}},
#     {'goalType': 'OWN',
#      'id': '779475be-7ab3-4e8a-8bd0-dc364a6b3693',
#      'images': {'PLAYER_CELEBRATING': 'https://img.uefa.com/imgml/TP/players/3/2024/900x1350/250028211.webp'},
#      'phase': 'SECOND_HALF',
#      'player': {'age': '31',
#       'birthDate': '1993-03-03',
#       'clubId': '50051',
#       'clubJerseyNumber': '22',
#       'clubShirtName': 'RÜDIGER',
#       'countryCode': 'GER',
#       'countryOfBirthCode': 'GER',
#       'detailedFieldPosition': 'CENTRE_BACK',
#       'fieldPosition': 'DEFENDER',
#       'gender': 'MALE',
#       'height': 190,
#       'id': '250028211',
#       'imageUrl': 'https://img.uefa.com/imgml/TP/players/3/2024/324x324/250028211.jpg',
#       'internationalName': 'Antonio Rüdiger',
#       'nationalFieldPosition': 'DEFENDER',
#       'nationalJerseyNumber': '2',
#       'nationalShirtName': 'Rüdiger',
#       'nationalTeamId': '47',
#       'translations': {'countryName': {'EN': 'Germany',
#         'FR': 'Allemagne',
#         'DE': 'Deutschland',
#         'ES': 'Alemania',
#         'PT': 'Alemanha',
#         'IT': 'Germania',
#         'RU': 'Германия',
#         'ZH': '德国',
#         'TR': 'Germany',
#         'HU': 'Germany',
#         'CS': 'Germany',
#         'NL': 'Germany'},
#        'countryOfBirthName': {'EN': 'Germany',
#         'FR': 'Allemagne',
#         'DE': 'Deutschland',
#         'ES': 'Alemania',
#         'PT': 'Alemanha',
#         'IT': 'Germania',
#         'RU': 'Германия',
#         'ZH': '德国',
#         'TR': 'Germany',
#         'HU': 'Germany',
#         'CS': 'Germany',
#         'NL': 'Germany'},
#        'fieldPosition': {'EN': 'Defender',
#         'FR': 'Défenseur',
#         'DE': 'Verteidiger',
#         'ES': 'Defensa',
#         'PT': 'Defesa',
#         'IT': 'Difensore',
#         'RU': 'Защитник',
#         'ZH': '后卫',
#         'TR': 'Defender',
#         'HU': 'Defender',
#         'CS': 'Defender',
#         'NL': 'Defender'},
#        'firstName': {'EN': 'Antonio',
#         'FR': 'Antonio',
#         'DE': 'Antonio',
#         'ES': 'Antonio',
#         'PT': 'Antonio',
#         'IT': 'Antonio',
#         'RU': 'Антонио',
#         'ZH': '安东尼奥',
#         'TR': 'Antonio',
#         'HU': 'Antonio',
#         'CS': 'Antonio',
#         'NL': 'Antonio'},
#        'lastName': {'EN': 'Rüdiger',
#         'FR': 'Rüdiger',
#         'DE': 'Rüdiger',
#         'ES': 'Rüdiger',
#         'PT': 'Rüdiger',
#         'IT': 'Rüdiger',
#         'RU': 'Рюдигер',
#         'ZH': '吕迪格',
#         'TR': 'Rüdiger',
#         'HU': 'Rüdiger',
#         'CS': 'Rüdiger',
#         'NL': 'Rüdiger'},
#        'name': {'EN': 'Antonio Rüdiger',
#         'FR': 'Antonio Rüdiger',
#         'DE': 'Antonio Rüdiger',
#         'ES': 'Antonio Rüdiger',
#         'PT': 'Antonio Rüdiger',
#         'IT': 'Antonio Rüdiger',
#         'RU': 'Антонио Рюдигер',
#         'ZH': '安东尼奥·吕迪格',
#         'TR': 'Antonio Rüdiger',
#         'HU': 'Antonio Rüdiger',
#         'CS': 'Antonio Rüdiger',
#         'NL': 'Antonio Rüdiger'},
#        'nationalFieldPosition': {'EN': 'Defender',
#         'FR': 'Défenseur',
#         'DE': 'Verteidiger',
#         'ES': 'Defensa',
#         'PT': 'Defesa',
#         'IT': 'Difensore',
#         'RU': 'Защитник',
#         'ZH': '后卫',
#         'TR': 'Defender',
#         'HU': 'Defender',
#         'CS': 'Defender',
#         'NL': 'Defender'},
#        'shortName': {'EN': 'Rüdiger',
#         'FR': 'Rüdiger',
#         'DE': 'Rüdiger',
#         'ES': 'Rüdiger',
#         'PT': 'Rüdiger',
#         'IT': 'Rüdiger',
#         'RU': 'Рюдигер',
#         'ZH': '吕迪格',
#         'TR': 'Rüdiger',
#         'HU': 'Rüdiger',
#         'CS': 'Rüdiger',
#         'NL': 'Rüdiger'}},
#       'weight': 85},
#      'teamId': '47',
#      'teamIdProvider': 'FAME',
#      'time': {'minute': 87, 'second': 32}},
#     {'goalType': 'SCORED',
#      'id': '4b1bd2e4-06a3-4b35-a022-730ee65d36c5',
#      'images': {'PLAYER_CELEBRATING': 'https://img.uefa.com/imgml/TP/players/3/2024/900x1350/250017824.webp'},
#      'phase': 'SECOND_HALF',
#      'player': {'age': '30',
#       'birthDate': '1994-01-12',
#       'clubId': '52758',
#       'clubJerseyNumber': '23',
#       'clubShirtName': 'Can',
#       'countryCode': 'GER',
#       'countryOfBirthCode': 'GER',
#       'detailedFieldPosition': 'DEFENSIVE_MIDFIELDER',
#       'fieldPosition': 'DEFENDER',
#       'gender': 'MALE',
#       'height': 184,
#       'id': '250017824',
#       'imageUrl': 'https://img.uefa.com/imgml/TP/players/3/2024/324x324/250017824.jpg',
#       'internationalName': 'Emre Can',
#       'nationalFieldPosition': 'MIDFIELDER',
#       'nationalJerseyNumber': '25',
#       'nationalShirtName': 'Can',
#       'nationalTeamId': '47',
#       'translations': {'countryName': {'EN': 'Germany',
#         'FR': 'Allemagne',
#         'DE': 'Deutschland',
#         'ES': 'Alemania',
#         'PT': 'Alemanha',
#         'IT': 'Germania',
#         'RU': 'Германия',
#         'ZH': '德国',
#         'TR': 'Germany',
#         'HU': 'Germany',
#         'CS': 'Germany',
#         'NL': 'Germany'},
#        'countryOfBirthName': {'EN': 'Germany',
#         'FR': 'Allemagne',
#         'DE': 'Deutschland',
#         'ES': 'Alemania',
#         'PT': 'Alemanha',
#         'IT': 'Germania',
#         'RU': 'Германия',
#         'ZH': '德国',
#         'TR': 'Germany',
#         'HU': 'Germany',
#         'CS': 'Germany',
#         'NL': 'Germany'},
#        'fieldPosition': {'EN': 'Defender',
#         'FR': 'Défenseur',
#         'DE': 'Verteidiger',
#         'ES': 'Defensa',
#         'PT': 'Defesa',
#         'IT': 'Difensore',
#         'RU': 'Защитник',
#         'ZH': '后卫',
#         'TR': 'Defender',
#         'HU': 'Defender',
#         'CS': 'Defender',
#         'NL': 'Defender'},
#        'firstName': {'EN': 'Emre',
#         'FR': 'Emre',
#         'DE': 'Emre',
#         'ES': 'Emre',
#         'PT': 'Emre',
#         'IT': 'Emre',
#         'RU': 'Эмре'},
#        'lastName': {'EN': 'Can',
#         'FR': 'Can',
#         'DE': 'Can',
#         'ES': 'Can',
#         'PT': 'Can',
#         'IT': 'Can',
#         'RU': 'Джан',
#         'ZH': '埃姆雷·詹',
#         'TR': 'Emre Can',
#         'HU': 'Emre Can',
#         'CS': 'Emre Can',
#         'NL': 'Emre Can'},
#        'name': {'EN': 'Emre Can',
#         'FR': 'Emre Can',
#         'DE': 'Emre Can',
#         'ES': 'Emre Can',
#         'PT': 'Emre Can',
#         'IT': 'Emre Can',
#         'RU': 'Эмре Джан',
#         'ZH': '埃姆雷·詹',
#         'TR': 'Emre Can',
#         'HU': 'Emre Can',
#         'CS': 'Emre Can',
#         'NL': 'Emre Can'},
#        'nationalFieldPosition': {'EN': 'Midfielder',
#         'FR': 'Milieu',
#         'DE': 'Mittelfeldspieler',
#         'ES': 'Centrocampista',
#         'PT': 'Médio',
#         'IT': 'Centrocampista',
#         'RU': 'Полузащитник',
#         'ZH': '中场球员',
#         'TR': 'Midfielder',
#         'HU': 'Midfielder',
#         'CS': 'Midfielder',
#         'NL': 'Midfielder'},
#        'shortName': {'EN': 'Can',
#         'FR': 'Can',
#         'DE': 'Can',
#         'ES': 'Can',
#         'PT': 'Can',
#         'IT': 'Can',
#         'RU': 'Джан',
#         'ZH': '埃姆雷·詹',
#         'TR': 'Emre Can',
#         'HU': 'Emre Can',
#         'CS': 'Emre Can',
#         'NL': 'Emre Can'}},
#       'weight': 82},
#      'teamId': '47',
#      'teamIdProvider': 'FAME',
#      'time': {'injuryMinute': 3, 'minute': 90, 'second': 34}}]},
#   'playerOfTheMatch': {'player': {'age': '21',
#     'birthDate': '2003-02-26',
#     'clubId': '50037',
#     'clubJerseyNumber': '42',
#     'clubShirtName': 'Musiala',
#     'countryCode': 'GER',
#     'countryOfBirthCode': 'GER',
#     'detailedFieldPosition': 'UNKNOWN',
#     'fieldPosition': 'MIDFIELDER',
#     'gender': 'MALE',
#     'id': '250124430',
#     'imageUrl': 'https://img.uefa.com/imgml/TP/players/3/2024/324x324/250124430.jpg',
#     'internationalName': 'Jamal Musiala',
#     'nationalFieldPosition': 'MIDFIELDER',
#     'nationalJerseyNumber': '10',
#     'nationalShirtName': 'Musiala',
#     'nationalTeamId': '47',
#     'translations': {'countryName': {'EN': 'Germany',
#       'FR': 'Allemagne',
#       'DE': 'Deutschland',
#       'ES': 'Alemania',
#       'PT': 'Alemanha',
#       'IT': 'Germania',
#       'RU': 'Германия',
#       'ZH': '德国',
#       'TR': 'Germany',
#       'HU': 'Germany',
#       'CS': 'Germany',
#       'NL': 'Germany'},
#      'countryOfBirthName': {'EN': 'Germany',
#       'FR': 'Allemagne',
#       'DE': 'Deutschland',
#       'ES': 'Alemania',
#       'PT': 'Alemanha',
#       'IT': 'Germania',
#       'RU': 'Германия',
#       'ZH': '德国',
#       'TR': 'Germany',
#       'HU': 'Germany',
#       'CS': 'Germany',
#       'NL': 'Germany'},
#      'fieldPosition': {'EN': 'Midfielder',
#       'FR': 'Milieu',
#       'DE': 'Mittelfeldspieler',
#       'ES': 'Centrocampista',
#       'PT': 'Médio',
#       'IT': 'Centrocampista',
#       'RU': 'Полузащитник',
#       'ZH': '中场球员',
#       'TR': 'Midfielder',
#       'HU': 'Midfielder',
#       'CS': 'Midfielder',
#       'NL': 'Midfielder'},
#      'firstName': {'EN': 'Jamal',
#       'FR': 'Jamal',
#       'DE': 'Jamal',
#       'ES': 'Jamal',
#       'PT': 'Jamal',
#       'IT': 'Jamal',
#       'RU': 'Джамал',
#       'ZH': '贾马尔',
#       'TR': 'Jamal',
#       'HU': 'Jamal',
#       'CS': 'Jamal',
#       'NL': 'Jamal'},
#      'lastName': {'EN': 'Musiala',
#       'FR': 'Musiala',
#       'DE': 'Musiala',
#       'ES': 'Musiala',
#       'PT': 'Musiala',
#       'IT': 'Musiala',
#       'RU': 'Мусиала',
#       'ZH': '穆夏拉',
#       'TR': 'Musiala',
#       'HU': 'Musiala',
#       'CS': 'Musiala',
#       'NL': 'Musiala'},
#      'name': {'EN': 'Jamal Musiala',
#       'FR': 'Jamal Musiala',
#       'DE': 'Jamal Musiala',
#       'ES': 'Jamal Musiala',
#       'PT': 'Jamal Musiala',
#       'IT': 'Jamal Musiala',
#       'RU': 'Джамал Мусиала',
#       'ZH': '贾马尔·穆夏拉',
#       'TR': 'Jamal Musiala',
#       'HU': 'Jamal Musiala',
#       'CS': 'Jamal Musiala',
#       'NL': 'Jamal Musiala'},
#      'nationalFieldPosition': {'EN': 'Midfielder',
#       'FR': 'Milieu',
#       'DE': 'Mittelfeldspieler',
#       'ES': 'Centrocampista',
#       'PT': 'Médio',
#       'IT': 'Centrocampista',
#       'RU': 'Полузащитник',
#       'ZH': '中场球员',
#       'TR': 'Midfielder',
#       'HU': 'Midfielder',
#       'CS': 'Midfielder',
#       'NL': 'Midfielder'},
#      'shortName': {'EN': 'Musiala',
#       'FR': 'Musiala',
#       'DE': 'Musiala',
#       'ES': 'Musiala',
#       'PT': 'Musiala',
#       'IT': 'Musiala',
#       'RU': 'Мусиала',
#       'ZH': '穆夏拉',
#       'TR': 'Musiala',
#       'HU': 'Musiala',
#       'CS': 'Musiala',
#       'NL': 'Musiala'}}},
#    'teamId': '47'},
#   'referees': [{'images': {'SMALL_SQUARE': 'https://img.uefa.com/imgml/referees/75x75/250107275.jpg'},
#     'person': {'countryCode': 'FRA',
#      'gender': 'MALE',
#      'id': '250107275',
#      'translations': {'countryName': {'EN': 'France',
#        'FR': 'France',
#        'DE': 'Frankreich',
#        'ES': 'Francia',
#        'PT': 'França',
#        'IT': 'Francia',
#        'RU': 'Франция',
#        'ZH': '法国',
#        'TR': 'France',
#        'HU': 'France',
#        'CS': 'France',
#        'NL': 'France'},
#       'firstName': {'EN': 'Willy',
#        'FR': 'Willy',
#        'DE': 'Willy',
#        'ES': 'Willy',
#        'PT': 'Willy',
#        'IT': 'Willy',
#        'RU': 'Вилли',
#        'ZH': 'Delajod',
#        'TR': 'Willy',
#        'HU': 'Willy',
#        'CS': 'Willy',
#        'NL': 'Willy'},
#       'lastName': {'EN': 'Delajod',
#        'FR': 'Delajod',
#        'DE': 'Delajod',
#        'ES': 'Delajod',
#        'PT': 'Delajod',
#        'IT': 'Delajod',
#        'RU': 'Делажо',
#        'ZH': 'Willy',
#        'TR': 'Delajod',
#        'HU': 'Delajod',
#        'CS': 'Delajod',
#        'NL': 'Delajod'},
#       'name': {'EN': 'Willy Delajod',
#        'FR': 'Willy Delajod',
#        'DE': 'Willy Delajod',
#        'ES': 'Willy Delajod',
#        'PT': 'Willy Delajod',
#        'IT': 'Willy Delajod',
#        'RU': 'Вилли Делажо',
#        'ZH': 'Delajod Willy',
#        'TR': 'Willy Delajod',
#        'HU': 'Willy Delajod',
#        'CS': 'Willy Delajod',
#        'NL': 'Willy Delajod'},
#       'shortName': {'EN': 'Delajod',
#        'FR': 'Delajod',
#        'DE': 'Delajod',
#        'ES': 'Delajod',
#        'PT': 'Delajod',
#        'IT': 'Delajod',
#        'RU': 'Делажо',
#        'ZH': 'Willy',
#        'TR': 'Delajod',
#        'HU': 'Delajod',
#        'CS': 'Delajod',
#        'NL': 'Delajod'}}},
#     'role': 'ASSISTANT_VIDEO_ASSISTANT_REFEREE_ONE',
#     'translations': {'roleName': {'EN': 'Assistant Video Assistant Referee 1',
#       'FR': "Assistant de l'Arbitre Assistant Vidéo 1",
#       'DE': 'Erster Assistent des Videoassistenten',
#       'ES': 'Asistente 1 del Árbitro Asistente de Vídeo',
#       'PT': 'Assistente de Vídeo Árbitro Assistente 1',
#       'IT': 'Assistente 1 Video Assistant Referee',
#       'RU': 'Ассистент видеопомощника рефери 1',
#       'ZH': 'Assistente de Vídeo Árbitro Assistente 1',
#       'TR': 'Assistant Video Assistant Referee 1',
#       'HU': 'Assistant Video Assistant Referee 1',
#       'CS': 'Assistant Video Assistant Referee 1',
#       'NL': 'Assistant Video Assistant Referee 1'}}},
#    {'images': {'SMALL_SQUARE': 'https://img.uefa.com/imgml/referees/75x75/250110346.jpg'},
#     'person': {'countryCode': 'FRA',
#      'gender': 'MALE',
#      'id': '250110346',
#      'translations': {'countryName': {'EN': 'France',
#        'FR': 'France',
#        'DE': 'Frankreich',
#        'ES': 'Francia',
#        'PT': 'França',
#        'IT': 'Francia',
#        'RU': 'Франция',
#        'ZH': '法国',
#        'TR': 'France',
#        'HU': 'France',
#        'CS': 'France',
#        'NL': 'France'},
#       'firstName': {'EN': 'Jérôme',
#        'FR': 'Jérôme',
#        'DE': 'Jérôme',
#        'ES': 'Jérôme',
#        'PT': 'Jérôme',
#        'IT': 'Jérôme',
#        'RU': 'Жером',
#        'ZH': 'Jérôme',
#        'TR': 'Jérôme',
#        'HU': 'Jérôme',
#        'CS': 'Jérôme',
#        'NL': 'Jérôme'},
#       'lastName': {'EN': 'Brisard',
#        'FR': 'Brisard',
#        'DE': 'Brisard',
#        'ES': 'Brisard',
#        'PT': 'Brisard',
#        'IT': 'Brisard',
#        'RU': 'Бризар',
#        'ZH': 'Brisard',
#        'TR': 'Brisard',
#        'HU': 'Brisard',
#        'CS': 'Brisard',
#        'NL': 'Brisard'},
#       'name': {'EN': 'Jérôme Brisard',
#        'FR': 'Jérôme Brisard',
#        'DE': 'Jérôme Brisard',
#        'ES': 'Jérôme Brisard',
#        'PT': 'Jérôme Brisard',
#        'IT': 'Jérôme Brisard',
#        'RU': 'Жером Бризар',
#        'ZH': 'Jérôme Brisard',
#        'TR': 'Jérôme Brisard',
#        'HU': 'Jérôme Brisard',
#        'CS': 'Jérôme Brisard',
#        'NL': 'Jérôme Brisard'},
#       'shortName': {'EN': 'Brisard',
#        'FR': 'Brisard',
#        'DE': 'Brisard',
#        'ES': 'Brisard',
#        'PT': 'Brisard',
#        'IT': 'Brisard',
#        'RU': 'Бризар',
#        'ZH': 'Brisard',
#        'TR': 'Brisard',
#        'HU': 'Brisard',
#        'CS': 'Brisard',
#        'NL': 'Brisard'}}},
#     'role': 'VIDEO_ASSISTANT_REFEREE',
#     'translations': {'roleName': {'EN': 'Video Assistant Referee',
#       'FR': 'Arbitre assistant vidéo',
#       'DE': 'Videoassistent',
#       'ES': 'Árbitro Asistente de Vídeo',
#       'PT': 'Vídeo Árbitro Assistente',
#       'IT': 'Video Assistant Referee',
#       'RU': 'Видеопомощник рефери',
#       'ZH': 'Vídeo Árbitro Assistente',
#       'TR': 'Video Assistant Referee',
#       'HU': 'Video Assistant Referee',
#       'CS': 'Video Assistant Referee',
#       'NL': 'Video Assistant Referee'}}},
#    {'images': {'SMALL_SQUARE': 'https://img.uefa.com/imgml/referees/75x75/250019501.jpg'},
#     'person': {'countryCode': 'FRA',
#      'gender': 'MALE',
#      'id': '250019501',
#      'translations': {'countryName': {'EN': 'France',
#        'FR': 'France',
#        'DE': 'Frankreich',
#        'ES': 'Francia',
#        'PT': 'França',
#        'IT': 'Francia',
#        'RU': 'Франция',
#        'ZH': '法国',
#        'TR': 'France',
#        'HU': 'France',
#        'CS': 'France',
#        'NL': 'France'},
#       'firstName': {'EN': 'Nicolas',
#        'FR': 'Nicolas',
#        'DE': 'Nicolas',
#        'ES': 'Nicolas',
#        'PT': 'Nicolas',
#        'IT': 'Nicolas',
#        'RU': 'Nicolas',
#        'ZH': 'Nicolas, Cyril, Maurice',
#        'TR': 'Nicolas, Cyril, Maurice',
#        'HU': 'Nicolas, Cyril, Maurice',
#        'CS': 'Nicolas, Cyril, Maurice',
#        'NL': 'Nicolas, Cyril, Maurice'},
#       'lastName': {'EN': 'Danos',
#        'FR': 'Danos',
#        'DE': 'Danos',
#        'ES': 'Danos',
#        'PT': 'Danos',
#        'IT': 'Danos',
#        'RU': 'Danos',
#        'ZH': 'Danos',
#        'TR': 'Danos',
#        'HU': 'Danos',
#        'CS': 'Danos',
#        'NL': 'Danos'},
#       'name': {'EN': 'Nicolas Danos',
#        'FR': 'Nicolas Danos',
#        'DE': 'Nicolas Danos',
#        'ES': 'Nicolas Danos',
#        'PT': 'Nicolas Danos',
#        'IT': 'Nicolas Danos',
#        'RU': 'Николя Дано',
#        'ZH': '尼古拉斯·达诺斯',
#        'TR': 'Nicolas Danos',
#        'HU': 'Nicolas Danos',
#        'CS': 'Nicolas Danos',
#        'NL': 'Nicolas Danos'},
#       'shortName': {'EN': 'Danos',
#        'FR': 'Danos',
#        'DE': 'Danos',
#        'ES': 'Danos',
#        'PT': 'Danos',
#        'IT': 'Danos',
#        'RU': 'Дано',
#        'ZH': '达诺斯',
#        'TR': 'Danos',
#        'HU': 'Danos',
#        'CS': 'Danos',
#        'NL': 'Danos'}}},
#     'role': 'ASSISTANT_REFEREE_ONE',
#     'translations': {'roleName': {'EN': 'Assistant referees',
#       'FR': 'Arbitres assistants',
#       'DE': 'Schiedsrichterassistenten',
#       'ES': 'Árbitros asistentes',
#       'PT': 'Árbitros assistentes',
#       'IT': 'Assistenti arbitrali',
#       'RU': 'Ассистенты рефери',
#       'ZH': 'Árbitros assistentes',
#       'TR': 'Assistant referees',
#       'HU': 'Assistant referees',
#       'CS': 'Assistant referees',
#       'NL': 'Assistant referees'}}},
#    {'images': {'SMALL_SQUARE': 'https://img.uefa.com/imgml/referees/75x75/250067161.jpg'},
#     'person': {'countryCode': 'ITA',
#      'gender': 'MALE',
#      'id': '250067161',
#      'translations': {'countryName': {'EN': 'Italy',
#        'FR': 'Italie',
#        'DE': 'Italien',
#        'ES': 'Italia',
#        'PT': 'Itália',
#        'IT': 'Italia',
#        'RU': 'Италия',
#        'ZH': '意大利',
#        'TR': 'Italy',
#        'HU': 'Italy',
#        'CS': 'Italy',
#        'NL': 'Italy'},
#       'firstName': {'EN': 'Massimiliano',
#        'FR': 'Massimiliano',
#        'DE': 'Massimiliano',
#        'ES': 'Massimiliano',
#        'PT': 'Massimiliano',
#        'IT': 'Massimiliano',
#        'RU': 'Massimiliano',
#        'ZH': 'Massimiliano',
#        'TR': 'Massimiliano',
#        'HU': 'Massimiliano',
#        'CS': 'Massimiliano',
#        'NL': 'Massimiliano'},
#       'lastName': {'EN': 'Irrati',
#        'FR': 'Irrati',
#        'DE': 'Irrati',
#        'ES': 'Irrati',
#        'PT': 'Irrati',
#        'IT': 'Irrati',
#        'RU': 'Irrati',
#        'ZH': 'Irrati',
#        'TR': 'Irrati',
#        'HU': 'Irrati',
#        'CS': 'Irrati',
#        'NL': 'Irrati'},
#       'name': {'EN': 'Massimiliano Irrati',
#        'FR': 'Massimiliano Irrati',
#        'DE': 'Massimiliano Irrati',
#        'ES': 'Massimiliano Irrati',
#        'PT': 'Massimiliano Irrati',
#        'IT': 'Massimiliano Irrati',
#        'RU': 'Массимилиано Иррати',
#        'ZH': '玛西米利亚诺·伊拉提',
#        'TR': 'Massimiliano Irrati',
#        'HU': 'Massimiliano Irrati',
#        'CS': 'Massimiliano Irrati',
#        'NL': 'Massimiliano Irrati'},
#       'shortName': {'EN': 'Irrati',
#        'FR': 'Irrati',
#        'DE': 'Irrati',
#        'ES': 'Irrati',
#        'PT': 'Irrati',
#        'IT': 'Irrati',
#        'RU': 'Иррати',
#        'ZH': '伊拉提',
#        'TR': 'Irrati',
#        'HU': 'Irrati',
#        'CS': 'Irrati',
#        'NL': 'Irrati'}}},
#     'role': 'ASSISTANT_VIDEO_ASSISTANT_REFEREE_TWO',
#     'translations': {'roleName': {'EN': 'Assistant Video Assistant Referee 2',
#       'FR': "Assistant de l'Arbitre Assistant Vidéo 2",
#       'DE': 'Zweiter Assistent des Videoassistenten',
#       'ES': 'Asistente 2 del Árbitro Asistente de Vídeo',
#       'PT': 'Assistente de Vídeo Árbitro Assistente 2',
#       'IT': 'Assistente 2 Video Assistant Referee',
#       'RU': 'Ассистент видеопомощника рефери 2',
#       'ZH': 'Assistente de Vídeo Árbitro Assistente 2',
#       'TR': 'Assistant Video Assistant Referee 2',
#       'HU': 'Assistant Video Assistant Referee 2',
#       'CS': 'Assistant Video Assistant Referee 2',
#       'NL': 'Assistant Video Assistant Referee 2'}}},
#    {'images': {'SMALL_SQUARE': 'https://img.uefa.com/imgml/referees/75x75/267055.jpg'},
#     'person': {'countryCode': 'ITA',
#      'gender': 'MALE',
#      'id': '267055',
#      'translations': {'countryName': {'EN': 'Italy',
#        'FR': 'Italie',
#        'DE': 'Italien',
#        'ES': 'Italia',
#        'PT': 'Itália',
#        'IT': 'Italia',
#        'RU': 'Италия',
#        'ZH': '意大利',
#        'TR': 'Italy',
#        'HU': 'Italy',
#        'CS': 'Italy',
#        'NL': 'Italy'},
#       'firstName': {'EN': 'Roberto',
#        'FR': 'Roberto',
#        'DE': 'Roberto',
#        'ES': 'Roberto',
#        'PT': 'Roberto',
#        'IT': 'Roberto',
#        'RU': 'Роберто',
#        'ZH': 'Roberto',
#        'TR': 'Roberto',
#        'HU': 'Roberto',
#        'CS': 'Roberto',
#        'NL': 'Roberto'},
#       'lastName': {'EN': 'Rosetti',
#        'FR': 'Rosetti',
#        'DE': 'Rosetti',
#        'ES': 'Rosetti',
#        'PT': 'Rosetti',
#        'IT': 'Rosetti',
#        'RU': 'Розетти',
#        'ZH': 'ROSETTI',
#        'TR': 'Rosetti',
#        'HU': 'Rosetti',
#        'CS': 'Rosetti',
#        'NL': 'Rosetti'},
#       'name': {'EN': 'Roberto Rosetti',
#        'FR': 'Roberto Rosetti',
#        'DE': 'Roberto Rosetti',
#        'ES': 'Roberto Rosetti',
#        'PT': 'Roberto Rosetti',
#        'IT': 'Roberto Rosetti',
#        'RU': 'Роберто Розетти',
#        'ZH': '罗伯托·罗赛蒂',
#        'TR': 'Roberto Rosetti',
#        'HU': 'Roberto Rosetti',
#        'CS': 'Roberto Rosetti',
#        'NL': 'Roberto Rosetti'},
#       'shortName': {'EN': 'Rosetti',
#        'FR': 'Rosetti',
#        'DE': 'Rosetti',
#        'ES': 'Rosetti',
#        'PT': 'Rosetti',
#        'IT': 'Rosetti',
#        'RU': 'Розетти',
#        'ZH': '罗赛蒂',
#        'TR': 'Rosetti',
#        'HU': 'Rosetti',
#        'CS': 'Rosetti',
#        'NL': 'Rosetti'}}},
#     'role': 'REFEREE_OBSERVER',
#     'translations': {'roleName': {'EN': 'Referee observer',
#       'FR': "Observateur d'arbitres",
#       'DE': 'Referee observer',
#       'ES': 'Observador arbitral',
#       'PT': 'Observador de árbitro',
#       'IT': 'Referee observer',
#       'RU': 'Судейский наблюдатель',
#       'ZH': 'Referee observer',
#       'TR': 'Referee observer',
#       'HU': 'Referee observer',
#       'CS': 'Referee observer',
#       'NL': 'Referee observer'}}},
#    {'images': {'SMALL_SQUARE': 'https://img.uefa.com/imgml/referees/75x75/250098867.jpg'},
#     'person': {'countryCode': 'FRA',
#      'gender': 'MALE',
#      'id': '250098867',
#      'translations': {'countryName': {'EN': 'France',
#        'FR': 'France',
#        'DE': 'Frankreich',
#        'ES': 'Francia',
#        'PT': 'França',
#        'IT': 'Francia',
#        'RU': 'Франция',
#        'ZH': '法国',
#        'TR': 'France',
#        'HU': 'France',
#        'CS': 'France',
#        'NL': 'France'},
#       'firstName': {'EN': 'François',
#        'FR': 'François',
#        'DE': 'François',
#        'ES': 'François',
#        'PT': 'François',
#        'IT': 'François',
#        'RU': 'Франсуа',
#        'ZH': 'François',
#        'TR': 'François',
#        'HU': 'François',
#        'CS': 'François',
#        'NL': 'François'},
#       'lastName': {'EN': 'Letexier',
#        'FR': 'Letexier',
#        'DE': 'Letexier',
#        'ES': 'Letexier',
#        'PT': 'Letexier',
#        'IT': 'Letexier',
#        'RU': 'Летесье',
#        'ZH': 'Letexier',
#        'TR': 'Letexier',
#        'HU': 'Letexier',
#        'CS': 'Letexier',
#        'NL': 'Letexier'},
#       'name': {'EN': 'François Letexier',
#        'FR': 'François Letexier',
#        'DE': 'François Letexier',
#        'ES': 'François Letexier',
#        'PT': 'François Letexier',
#        'IT': 'François Letexier',
#        'RU': 'Франсуа Летесье',
#        'ZH': 'François Letexier',
#        'TR': 'François Letexier',
#        'HU': 'François Letexier',
#        'CS': 'François Letexier',
#        'NL': 'François Letexier'},
#       'shortName': {'EN': 'Letexier',
#        'FR': 'Letexier',
#        'DE': 'Letexier',
#        'ES': 'Letexier',
#        'PT': 'Letexier',
#        'IT': 'Letexier',
#        'RU': 'Летесье',
# ...
#       'FR': 'Arbitre assistant vidéo',
#       'DE': 'Videoassistent',
#       'ES': 'Árbitro Asistente de Vídeo',
#       'PT': 'Vídeo Árbitro Assistente',
#       'IT': 'Video Assistant Referee',
#       'RU': 'Видеопомощник рефери',
#       'ZH': 'Vídeo Árbitro Assistente',
#       'TR': 'Video Assistant Referee',
#       'HU': 'Video Assistant Referee',
#       'CS': 'Video Assistant Referee',
#       'NL': 'Video Assistant Referee'}}},
#    {'images': {'SMALL_SQUARE': 'https://img.uefa.com/imgml/referees/75x75/250081331.jpg'},
#     'person': {'countryCode': 'FRA',
#      'gender': 'MALE',
#      'id': '250081331',
#      'translations': {'countryName': {'EN': 'France',
#        'FR': 'France',
#        'DE': 'Frankreich',
#        'ES': 'Francia',
#        'PT': 'França',
#        'IT': 'Francia',
#        'RU': 'Франция',
#        'ZH': '法国',
#        'TR': 'France',
#        'HU': 'France',
#        'CS': 'France',
#        'NL': 'France'},
#       'firstName': {'EN': 'Cyril',
#        'FR': 'Cyril',
#        'DE': 'Cyril',
#        'ES': 'Cyril',
#        'PT': 'Cyril',
#        'IT': 'Cyril',
#        'RU': 'Cyril',
#        'ZH': 'Cyril',
#        'TR': 'Cyril',
#        'HU': 'Cyril',
#        'CS': 'Cyril',
#        'NL': 'Cyril'},
#       'lastName': {'EN': 'Mugnier',
#        'FR': 'Mugnier',
#        'DE': 'Mugnier',
#        'ES': 'Mugnier',
#        'PT': 'Mugnier',
#        'IT': 'Mugnier',
#        'RU': 'Mugnier',
#        'ZH': 'Mugnier',
#        'TR': 'Mugnier',
#        'HU': 'Mugnier',
#        'CS': 'Mugnier',
#        'NL': 'Mugnier'},
#       'name': {'EN': 'Cyril Mugnier',
#        'FR': 'Cyril Mugnier',
#        'DE': 'Cyril Mugnier',
#        'ES': 'Cyril Mugnier',
#        'PT': 'Cyril Mugnier',
#        'IT': 'Cyril Mugnier',
#        'RU': 'Сириль Мюнье',
#        'ZH': 'Cyril Mugnier',
#        'TR': 'Cyril Mugnier',
#        'HU': 'Cyril Mugnier',
#        'CS': 'Cyril Mugnier',
#        'NL': 'Cyril Mugnier'},
#       'shortName': {'EN': 'Mugnier',
#        'FR': 'Mugnier',
#        'DE': 'Mugnier',
#        'ES': 'Mugnier',
#        'PT': 'Mugnier',
#        'IT': 'Mugnier',
#        'RU': 'Мюнье',
#        'ZH': 'Mugnier',
#        'TR': 'Mugnier',
#        'HU': 'Mugnier',
#        'CS': 'Mugnier',
#        'NL': 'Mugnier'}}},
#     'role': 'ASSISTANT_REFEREE_ONE',
#     'translations': {'roleName': {'EN': 'Assistant referees',
#       'FR': 'Arbitres assistants',
#       'DE': 'Schiedsrichterassistenten',
#       'ES': 'Árbitros asistentes',
#       'PT': 'Árbitros assistentes',
#       'IT': 'Assistenti arbitrali',
#       'RU': 'Ассистенты рефери',
#       'ZH': 'Árbitros assistentes',
#       'TR': 'Assistant referees',
#       'HU': 'Assistant referees',
#       'CS': 'Assistant referees',
#       'NL': 'Assistant referees'}}},
#    {'images': {'SMALL_SQUARE': 'https://img.uefa.com/imgml/referees/75x75/290689.jpg'},
#     'person': {'countryCode': 'NED',
#      'gender': 'MALE',
#      'id': '290689',
#      'translations': {'countryName': {'EN': 'Netherlands',
#        'FR': 'Pays-Bas',
#        'DE': 'Niederlande',
#        'ES': 'Holanda',
#        'PT': 'Holanda',
#        'IT': 'Olanda',
#        'RU': 'Нидерланды',
#        'ZH': '荷兰',
#        'TR': 'Netherlands',
#        'HU': 'Netherlands',
#        'CS': 'Netherlands',
#        'NL': 'Netherlands'},
#       'firstName': {'EN': 'Bjorn',
#        'FR': 'Bjorn',
#        'DE': 'Bjorn',
#        'ES': 'Bjorn',
#        'PT': 'Bjorn',
#        'IT': 'Bjorn',
#        'RU': 'Bjorn',
#        'ZH': 'Bjorn',
#        'TR': 'Bjorn',
#        'HU': 'Bjorn',
#        'CS': 'Bjorn',
#        'NL': 'Bjorn'},
#       'lastName': {'EN': 'Kuipers',
#        'FR': 'Kuipers',
#        'DE': 'Kuipers',
#        'ES': 'Kuipers',
#        'PT': 'Kuipers',
#        'IT': 'Kuipers',
#        'RU': 'Kuipers',
#        'ZH': 'Kuipers',
#        'TR': 'Kuipers',
#        'HU': 'Kuipers',
#        'CS': 'Kuipers',
#        'NL': 'Kuipers'},
#       'name': {'EN': 'Björn Kuipers',
#        'FR': 'Björn Kuipers',
#        'DE': 'Björn Kuipers',
#        'ES': 'Björn Kuipers',
#        'PT': 'Björn Kuipers',
#        'IT': 'Björn Kuipers',
#        'RU': 'Бьорн Кейперс',
#        'ZH': '伯约恩·奎佩尔斯',
#        'TR': 'Björn Kuipers',
#        'HU': 'Björn Kuipers',
#        'CS': 'Björn Kuipers',
#        'NL': 'Björn Kuipers'},
#       'shortName': {'EN': 'Kuipers',
#        'FR': 'Kuipers',
#        'DE': 'Kuipers',
#        'ES': 'Kuipers',
#        'PT': 'Kuipers',
#        'IT': 'Kuipers',
#        'RU': 'Кейперс',
#        'ZH': '奎佩尔斯',
#        'TR': 'Kuipers',
#        'HU': 'Kuipers',
#        'CS': 'Kuipers',
#        'NL': 'Kuipers'}}},
#     'role': 'REFEREE_OBSERVER',
#     'translations': {'roleName': {'EN': 'Referee observer',
#       'FR': "Observateur d'arbitres",
#       'DE': 'Referee observer',
#       'ES': 'Observador arbitral',
#       'PT': 'Observador de árbitro',
#       'IT': 'Referee observer',
#       'RU': 'Судейский наблюдатель',
#       'ZH': 'Referee observer',
#       'TR': 'Referee observer',
#       'HU': 'Referee observer',
#       'CS': 'Referee observer',
#       'NL': 'Referee observer'}}},
#    {'images': {'SMALL_SQUARE': 'https://img.uefa.com/imgml/referees/75x75/150369063.jpg'},
#     'person': {'countryCode': 'FRA',
#      'gender': 'MALE',
#      'id': '150369063',
#      'translations': {'countryName': {'EN': 'France',
#        'FR': 'France',
#        'DE': 'Frankreich',
#        'ES': 'Francia',
#        'PT': 'França',
#        'IT': 'Francia',
#        'RU': 'Франция',
#        'ZH': '法国',
#        'TR': 'France',
#        'HU': 'France',
#        'CS': 'France',
#        'NL': 'France'},
#       'firstName': {'EN': 'Mehdi',
#        'FR': 'Mehdi',
#        'DE': 'Mehdi',
#        'ES': 'Mehdi',
#        'PT': 'Mehdi',
#        'IT': 'Mehdi',
#        'RU': 'Mehdi',
#        'ZH': 'Mehdi',
#        'TR': 'Mehdi',
#        'HU': 'Mehdi',
#        'CS': 'Mehdi',
#        'NL': 'Mehdi'},
#       'lastName': {'EN': 'Rahmouni',
#        'FR': 'Rahmouni',
#        'DE': 'Rahmouni',
#        'ES': 'Rahmouni',
#        'PT': 'Rahmouni',
#        'IT': 'Rahmouni',
#        'RU': 'Rahmouni',
#        'ZH': 'Rahmouni',
#        'TR': 'Rahmouni',
#        'HU': 'Rahmouni',
#        'CS': 'Rahmouni',
#        'NL': 'Rahmouni'},
#       'name': {'EN': 'Mehdi Rahmouni',
#        'FR': 'Mehdi Rahmouni',
#        'DE': 'Mehdi Rahmouni',
#        'ES': 'Mehdi Rahmouni',
#        'PT': 'Mehdi Rahmouni',
#        'IT': 'Mehdi Rahmouni',
#        'RU': 'Меди Рамуни',
#        'ZH': 'Mehdi Rahmouni',
#        'TR': 'Mehdi Rahmouni',
#        'HU': 'Mehdi Rahmouni',
#        'CS': 'Mehdi Rahmouni',
#        'NL': 'Mehdi Rahmouni'},
#       'shortName': {'EN': 'Rahmouni',
#        'FR': 'Rahmouni',
#        'DE': 'Rahmouni',
#        'ES': 'Rahmouni',
#        'PT': 'Rahmouni',
#        'IT': 'Rahmouni',
#        'RU': 'Рамуни',
#        'ZH': 'Rahmouni',
#        'TR': 'Rahmouni',
#        'HU': 'Rahmouni',
#        'CS': 'Rahmouni',
#        'NL': 'Rahmouni'}}},
#     'role': 'ASSISTANT_REFEREE_TWO',
#     'translations': {'roleName': {'EN': 'Assistant referee two',
#       'FR': 'Arbitre assistant n°2',
#       'DE': 'Schiedsrichterassistent zwei',
#       'ES': 'Segundo árbitro asistente',
#       'PT': 'Árbitro assistente 2',
#       'IT': 'Guardalinee due',
#       'RU': 'Ассистент рефери 2',
#       'ZH': 'Árbitro-assistente 2',
#       'TR': 'Assistant referee two',
#       'HU': 'Assistant referee two',
#       'CS': 'Assistant referee two',
#       'NL': 'Assistant referee two'}}},
#    {'images': {'SMALL_SQUARE': 'https://img.uefa.com/imgml/referees/75x75/250107275.jpg'},
#     'person': {'countryCode': 'FRA',
#      'gender': 'MALE',
#      'id': '250107275',
#      'translations': {'countryName': {'EN': 'France',
#        'FR': 'France',
#        'DE': 'Frankreich',
#        'ES': 'Francia',
#        'PT': 'França',
#        'IT': 'Francia',
#        'RU': 'Франция',
#        'ZH': '法国',
#        'TR': 'France',
#        'HU': 'France',
#        'CS': 'France',
#        'NL': 'France'},
#       'firstName': {'EN': 'Willy',
#        'FR': 'Willy',
#        'DE': 'Willy',
#        'ES': 'Willy',
#        'PT': 'Willy',
#        'IT': 'Willy',
#        'RU': 'Вилли',
#        'ZH': 'Delajod',
#        'TR': 'Willy',
#        'HU': 'Willy',
#        'CS': 'Willy',
#        'NL': 'Willy'},
#       'lastName': {'EN': 'Delajod',
#        'FR': 'Delajod',
#        'DE': 'Delajod',
#        'ES': 'Delajod',
#        'PT': 'Delajod',
#        'IT': 'Delajod',
#        'RU': 'Делажо',
#        'ZH': 'Willy',
#        'TR': 'Delajod',
#        'HU': 'Delajod',
#        'CS': 'Delajod',
#        'NL': 'Delajod'},
#       'name': {'EN': 'Willy Delajod',
#        'FR': 'Willy Delajod',
#        'DE': 'Willy Delajod',
#        'ES': 'Willy Delajod',
#        'PT': 'Willy Delajod',
#        'IT': 'Willy Delajod',
#        'RU': 'Вилли Делажо',
#        'ZH': 'Delajod Willy',
#        'TR': 'Willy Delajod',
#        'HU': 'Willy Delajod',
#        'CS': 'Willy Delajod',
#        'NL': 'Willy Delajod'},
#       'shortName': {'EN': 'Delajod',
#        'FR': 'Delajod',
#        'DE': 'Delajod',
#        'ES': 'Delajod',
#        'PT': 'Delajod',
#        'IT': 'Delajod',
#        'RU': 'Делажо',
#        'ZH': 'Willy',
#        'TR': 'Delajod',
#        'HU': 'Delajod',
#        'CS': 'Delajod',
#        'NL': 'Delajod'}}},
#     'role': 'ASSISTANT_VIDEO_ASSISTANT_REFEREE_ONE',
#     'translations': {'roleName': {'EN': 'Assistant Video Assistant Referee 1',
#       'FR': "Assistant de l'Arbitre Assistant Vidéo 1",
#       'DE': 'Erster Assistent des Videoassistenten',
#       'ES': 'Asistente 1 del Árbitro Asistente de Vídeo',
#       'PT': 'Assistente de Vídeo Árbitro Assistente 1',
#       'IT': 'Assistente 1 Video Assistant Referee',
#       'RU': 'Ассистент видеопомощника рефери 1',
#       'ZH': 'Assistente de Vídeo Árbitro Assistente 1',
#       'TR': 'Assistant Video Assistant Referee 1',
#       'HU': 'Assistant Video Assistant Referee 1',
#       'CS': 'Assistant Video Assistant Referee 1',
#       'NL': 'Assistant Video Assistant Referee 1'}}},
#    {'images': {'SMALL_SQUARE': 'https://img.uefa.com/imgml/referees/75x75/250019292.jpg'},
#     'person': {'countryCode': 'POL',
#      'gender': 'MALE',
#      'id': '250019292',
#      'translations': {'countryName': {'EN': 'Poland',
#        'FR': 'Pologne',
#        'DE': 'Polen',
#        'ES': 'Polonia',
#        'PT': 'Polónia',
#        'IT': 'Polonia',
#        'RU': 'Польша',
#        'ZH': '波兰',
#        'TR': 'Poland',
#        'HU': 'Poland',
#        'CS': 'Poland',
#        'NL': 'Poland'},
#       'firstName': {'EN': 'Szymon',
#        'FR': 'Szymon',
#        'DE': 'Szymon',
#        'ES': 'Szymon',
#        'PT': 'Szymon',
#        'IT': 'Szymon',
#        'RU': 'Szymon',
#        'ZH': 'Szymon',
#        'TR': 'Szymon',
#        'HU': 'Szymon',
#        'CS': 'Szymon',
#        'NL': 'Szymon'},
#       'lastName': {'EN': 'Marciniak',
#        'FR': 'Marciniak',
#        'DE': 'Marciniak',
#        'ES': 'Marciniak',
#        'PT': 'Marciniak',
#        'IT': 'Marciniak',
#        'RU': 'Marciniak',
#        'ZH': 'Marciniak',
#        'TR': 'Marciniak',
#        'HU': 'Marciniak',
#        'CS': 'Marciniak',
#        'NL': 'Marciniak'},
#       'name': {'EN': 'Szymon Marciniak',
#        'FR': 'Szymon Marciniak',
#        'DE': 'Szymon Marciniak',
#        'ES': 'Szymon Marciniak',
#        'PT': 'Szymon Marciniak',
#        'IT': 'Szymon Marciniak',
#        'RU': 'Шимон Марчиняк',
#        'ZH': '茨摩恩·马尔齐尼亚克',
#        'TR': 'Szymon Marciniak',
#        'HU': 'Szymon Marciniak',
#        'CS': 'Szymon Marciniak',
#        'NL': 'Szymon Marciniak'},
#       'shortName': {'EN': 'Marciniak',
#        'FR': 'Marciniak',
#        'DE': 'Marciniak',
#        'ES': 'Marciniak',
#        'PT': 'Marciniak',
#        'IT': 'Marciniak',
#        'RU': 'Марчиняк',
#        'ZH': '马尔齐尼亚克',
#        'TR': 'Marciniak',
#        'HU': 'Marciniak',
#        'CS': 'Marciniak',
#        'NL': 'Marciniak'}}},
#     'role': 'FOURTH_OFFICIAL',
#     'translations': {'roleName': {'EN': 'Fourth official',
#       'FR': 'Quatrième arbitre',
#       'DE': 'Vierter Offizieller',
#       'ES': 'Cuarto árbitro',
#       'PT': 'Quarto árbitro',
#       'IT': 'Quarto uomo',
#       'RU': 'Четвертый рефери',
#       'ZH': 'Quarto árbitro',
#       'TR': 'Fourth official',
#       'HU': 'Fourth official',
#       'CS': 'Fourth official',
#       'NL': 'Fourth official'}}}],
#   'round': {'active': True,
#    'benchGKCount': 3,
#    'benchPlayersCount': 15,
#    'benchStaffCount': 11,
#    'coefficientWinnerBonus': 0.0,
#    'competitionId': '3',
#    'dateFrom': '2024-07-13T22:00:00+0000',
#    'dateTo': '2024-07-14T21:59:59+0000',
#    'fieldPlayersCount': 11,
#    'groupCount': 1,
#    'id': '2001083',
#    'metaData': {'name': 'Final', 'type': 'FINAL'},
#    'mode': 'FINAL',
#    'modeDetail': 'KNOCK_OUT_ONE_LEG',
#    'orderInCompetition': 8,
#    'phase': 'TOURNAMENT',
#    'seasonYear': '2024',
#    'secondaryType': 'FINALS',
#    'stadiumNameType': 'SPECIAL_EVENTS_NAME',
#    'status': 'FINISHED',
#    'substitutionCount': 3,
#    'teamCount': 2,
#    'teams': ['122', '39'],
#    'translations': {'abbreviation': {'EN': 'Final',
#      'FR': 'F',
#      'DE': 'Finale',
#      'ES': 'F.',
#      'PT': 'F.',
#      'IT': 'F.',
#      'RU': 'Финал',
#      'ZH': 'Final',
#      'TR': 'Final',
#      'HU': 'Final',
#      'CS': 'Final',
#      'NL': 'Final'},
#     'name': {'EN': 'Final',
#      'FR': 'Finale',
#      'DE': 'Finale',
#      'ES': 'Final',
#      'PT': 'Final',
#      'IT': 'Finale',
#      'RU': 'Финал',
#      'ZH': 'Final',
#      'TR': 'Final',
#      'HU': 'Final',
#      'CS': 'Final',
#      'NL': 'Final'},
#     'shortName': {'EN': 'Final',
#      'FR': 'F',
#      'DE': 'Finale',
#      'ES': 'Final',
#      'PT': 'F.',
#      'IT': 'F.',
#      'RU': 'Финал',
#      'ZH': 'Final',
#      'TR': 'Final',
#      'HU': 'Final',
#      'CS': 'Final',
#      'NL': 'Final'}}},
#   'seasonYear': '2024',
#   'sessionNumber': 1,
#   'stadium': {'address': 'Olympischer Platz 3',
#    'capacity': 74244,
#    'city': {'countryCode': 'GER',
#     'id': '1225',
#     'translations': {'name': {'EN': 'Berlin',
#       'FR': 'Berlin',
#       'DE': 'Berlin',
#       'ES': 'Berlín',
#       'PT': 'Berlim',
#       'IT': 'Berlino',
#       'RU': 'Берлин',
#       'ZH': '柏林',
#       'TR': 'Berlin',
#       'HU': 'Berlin',
#       'CS': 'Berlin',
#       'NL': 'Berlin'}}},
#    'countryCode': 'GER',
#    'geolocation': {'latitude': 52.5147139, 'longitude': 13.2393972},
#    'id': '62875',
#    'images': {'MEDIUM_WIDE': 'https://img.uefa.com/imgml/stadium/matchinfo/w1/62875.jpg',
#     'LARGE_ULTRA_WIDE': 'https://img.uefa.com/imgml/stadium/matchinfo/uw/62875.jpg'},
#    'openingDate': '1936-01-01',
#    'pitch': {'length': 105, 'width': 68},
#    'translations': {'mediaName': {'EN': 'Olympiastadion',
#      'FR': 'Olympiastadion',
#      'DE': 'Olympiastadion',
#      'ES': 'Olympiastadion',
#      'PT': 'Olympiastadion',
#      'IT': 'Olympiastadion',
#      'RU': 'Олимпиаштадион',
#      'ZH': 'Olympiastadion',
#      'TR': 'Olympiastadion',
#      'HU': 'Olympiastadion',
#      'CS': 'Olympiastadion',
#      'NL': 'Olympiastadion'},
#     'name': {'EN': 'Olympiastadion',
#      'FR': 'Olympiastadion',
#      'DE': 'Olympiastadion',
#      'ES': 'Olympiastadion',
#      'PT': 'Olympiastadion',
#      'IT': 'Olympiastadion',
#      'RU': 'Олимпиаштадион',
#      'ZH': 'Olympiastadion',
#      'TR': 'Olympiastadion',
#      'HU': 'Olympiastadion',
#      'CS': 'Olympiastadion',
#      'NL': 'Olympiastadion'},
#     'officialName': {'EN': 'Olympiastadion',
#      'FR': 'Olympiastadion',
#      'DE': 'Olympiastadion',
#      'ES': 'Olympiastadion',
#      'PT': 'Olympiastadion',
#      'IT': 'Olympiastadion',
#      'RU': 'Олимпиаштадион',
#      'ZH': 'Olympiastadion',
#      'TR': 'Olympiastadion',
#      'HU': 'Olympiastadion',
#      'CS': 'Olympiastadion',
#      'NL': 'Olympiastadion'},
#     'specialEventsName': {'EN': 'Olympiastadion',
#      'FR': 'Olympiastadion',
#      'DE': 'Olympiastadion',
#      'ES': 'Olympiastadion',
#      'PT': 'Olympiastadion',
#      'IT': 'Olympiastadion',
#      'RU': 'Олимпиаштадион',
#      'ZH': 'Olympiastadion',
#      'TR': 'Olympiastadion',
#      'HU': 'Olympiastadion',
#      'CS': 'Olympiastadion',
#      'NL': 'Olympiastadion'},
#     'sponsorName': {'EN': 'Olympiastadion',
#      'FR': 'Olympiastadion',
#      'DE': 'Olympiastadion',
#      'ES': 'Olympiastadion',
#      'PT': 'Olympiastadion',
#      'IT': 'Olympiastadion',
#      'RU': 'Олимпиаштадион',
#      'ZH': 'Olympiastadion',
#      'TR': 'Olympiastadion',
#      'HU': 'Olympiastadion',
#      'CS': 'Olympiastadion',
#      'NL': 'Olympiastadion'}}},
#   'status': 'UPCOMING',
#   'type': 'SINGLE'}]

# %%
def get_match_data(id):
    url = "https://match.uefa.com/v5/matches?matchId=%s" % id
    res = requests.get(url,headers=headers)
    data = json.loads(res.text)[0]
    #   'id', 比赛id
    #   'awayTeam', 客场球队信息
    #       'id' 客场球队id
    #       'translation'
    #           'countryname'
    #               'ZH' 客场球队中文名称
    #   'homeTeam', 主场球队信息
    #       'id' 主场球队id
    #       'translation'
    #           'countryname'
    #               'ZH' 主场球队中文名称
    #   'score', 比分
    #       'regular' 常规时间比分
    #           'away' 客场球队得分
    #           'home' 主场球队得分
    #       'total' 全场比赛比分
    #           'away' 客场球队得分
    #           'home' 主场球队得分
    #   'playerOfTheMatch', 本场mvp球员
    #       'player'
    #           'translation'
    #               'name'
    #                   'ZH' 球员中文名
    #               'nationalFieldPosition'
    #                   'ZH' 球员位置（此项目中使用国家队位置）
    #   'playerEvents', 球员事件，红黄牌、进球等

    #   'behindClosedDoors', 非公开?不重要
    #   'competition', 比赛基本信息，比如成人组、男子、比赛类别（杯赛）等
    #   'fullTimeAt', 完赛时间
    #   'group', 组
    #   'kickOffTime', 比赛开始时间
    #   'lineupStatus',
    #   'matchAttendance',
    #   'matchNumber',
    #   'matchday', 比赛日信息
    #   'referees', 裁判信息
    #   'round', 系列赛阶段信息，小组赛、淘汰赛等
    #   'seasonYear', 
    #   'sessionNumber',
    #   'stadium', 球馆信息
    #   'status', 比赛状态
    #   'type', 小组赛？这个字段不确定
    #   'winner' 获胜球队

    need_match_data = [
        data['id'],
        data['awayTeam']['id'],
        data['awayTeam']['translations']['countryName']['ZH'],
        data['homeTeam']['id'],
        data['homeTeam']['translations']['countryName']['ZH'],
        data['score']['regular']['away'],
        data['score']['regular']['home'],
        data['score']['total']['away'],
        data['score']['total']['home'],
        data['playerOfTheMatch']['player']['translations']['name']['ZH'],
        data['playerOfTheMatch']['player']['translations']['nationalFieldPosition']['ZH'],
    ]
    return need_match_data

# match_data = get_match_data(2036161)
match_data = []
for i in tqdm(match_ids):
    match_data.append(get_match_data(i))
    time.sleep(0.5)
    
match_data = pd.DataFrame(match_data,columns=['match_id','away_team_id','away_team_name','home_team_id','home_team_name','away_score','home_score','total_away_score','total_home_score','mvp_name','mvp_position'])
match_data.to_excel('..\\data\\match_data.xlsx',index=False)

# %%
match_data
# Out:
# ['2036161', '117', '苏格兰', '47', '德国', 1, 5, 1, 5, '贾马尔·穆夏拉', '中场球员']

# %%
# 爬取球队数据
url = "https://matchstats.uefa.com/v1/team-statistics/%d" % 2036161
res = requests.get(url,headers=headers)
data = json.loads(res.text)
data
# Out:
# [{'statistics': [{'attributes': {'DistanceMeters': '103682'},
#     'name': 'distance_covered',
#     'translations': {'name': {'EN': 'Distance covered (km)',
#       'FR': 'Distance parcourue (km)',
#       'DE': 'Zurückgelegte Distanz (km)',
#       'ES': 'Distancia recorrida (km)',
#       'PT': 'Distância percorrida (km)',
#       'IT': 'Distanza coperta (km)',
#       'RU': 'Дистанция (км)',
#       'ZH': 'distance_covered',
#       'TR': 'Distance covered (km)',
#       'HU': 'Distance covered (km)',
#       'CS': 'Distance covered (km)',
#       'NL': 'Distance covered (km)'}},
#     'unit': 'KILOMETER',
#     'value': '103.68'},
#    {'attributes': {'DistanceMeters': '35961'},
#     'name': 'distance_covered_in_possession',
#     'translations': {'name': {'EN': 'distance covered in possession',
#       'FR': 'distance parcourue avec le ballon',
#       'DE': 'distance covered in possession',
#       'ES': 'distancia recorrida con la posesión',
#       'PT': 'distância percorrida com a bola',
#       'IT': 'distance covered in possession',
#       'RU': 'дистанция с мячом',
#       'ZH': 'distance covered in possession',
#       'TR': 'distance covered in possession',
#       'HU': 'distance covered in possession',
#       'CS': 'distance covered in possession',
#       'NL': 'distance covered in possession'}},
#     'unit': 'KILOMETER',
#     'value': '35.96'},
#    {'attributes': {'DistanceMeters': '55978'},
#     'name': 'distance_covered_opponent_team_in_possession',
#     'translations': {'name': {'EN': 'distance covered while opponent team is in possession',
#       'FR': 'distance covered while opponent team is in possession',
#       'DE': 'distance covered while opponent team is in possession',
#       'ES': 'Distancia recorrida cuando el equipo rival tiene la posesión',
#       'PT': 'distância percorrida com o adversário em posse de bola',
#       'IT': 'distance covered while opponent team is in possession',
#       'RU': 'distance covered while opponent team is in possession',
#       'ZH': 'distance covered while opponent team is in possession',
#       'TR': 'distance covered while opponent team is in possession',
#       'HU': 'distance covered while opponent team is in possession',
#       'CS': 'distance covered while opponent team is in possession',
#       'NL': 'distance covered while opponent team is in possession'}},
#     'unit': 'KILOMETER',
#     'value': '55.97'},
#    {'attributes': {'DistanceMeters': '860'},
#     'name': 'distance_covered_in_standing_activity',
#     'translations': {'name': {'EN': 'Distance covered when standing',
#       'FR': 'Distance parcourue en étant presque immobile',
#       'DE': 'Zurückgelegte Entfernung im Stehen',
#       'ES': 'Distancia recorrida estando de pie',
#       'PT': 'Distância percorrida em pé',
#       'IT': 'Distanza percorsa da fermo',
#       'RU': 'distance covered in standing activity',
#       'ZH': 'distance covered in standing activity',
#       'TR': 'Distance covered when standing',
#       'HU': 'Distance covered when standing',
#       'CS': 'Distance covered when standing',
#       'NL': 'Distance covered when standing'}},
#     'unit': 'KILOMETER',
#     'value': '0.86'},
#    {'attributes': {'DistanceMeters': '38271'},
#     'name': 'distance_covered_in_walking_activity',
#     'translations': {'name': {'EN': 'Distance covered when walking',
#       'FR': 'Distance parcourue en marchant',
#       'DE': 'Zurückgelegte Entfernung im Gehen',
#       'ES': 'Distancia recorrida caminando',
#       'PT': 'Distância percorrida a andar',
#       'IT': 'Distanza percorsa camminando',
#       'RU': 'distance covered in walking activity',
#       'ZH': 'distance covered in walking activity',
#       'TR': 'Distance covered when walking',
#       'HU': 'Distance covered when walking',
#       'CS': 'Distance covered when walking',
#       'NL': 'Distance covered when walking'}},
#     'unit': 'KILOMETER',
#     'value': '38.27'},
#    {'attributes': {'DistanceMeters': '44917'},
#     'name': 'distance_covered_in_jogging_activity',
#     'translations': {'name': {'EN': 'Distance covered when jogging',
#       'FR': 'Distance parcourue en footing',
#       'DE': 'Zurückgelegte Entfernung bei mittelschnellen Läufen',
#       'ES': 'Distancia cubierta en carrera de intensidad media',
#       'PT': 'Distância percorrida em corrida moderada',
#       'IT': 'Distanza percorsa in corsa leggera',
#       'RU': 'distance covered in jogging activity',
#       'ZH': 'distance covered in jogging activity',
#       'TR': 'Distance covered when jogging',
#       'HU': 'Distance covered when jogging',
#       'CS': 'Distance covered when jogging',
#       'NL': 'Distance covered when jogging'}},
#     'unit': 'KILOMETER',
#     'value': '44.91'},
#    {'attributes': {'DistanceMeters': '12751'},
#     'name': 'distance_covered_in_low_activity_running',
#     'translations': {'name': {'EN': 'Distance covered in low-activity running',
#       'FR': 'Distance parcourue à vitesse modérée',
#       'DE': 'Zurückgelegte Entfernung bei langsamen Läufen',
#       'ES': 'Distancia recorrida en carrera de baja intensidad',
#       'PT': 'Rácio de distância percorrida em corrida de baixa intensidade',
#       'IT': 'Distanza percorsa in corsa a bassa intensità',
#       'RU': 'distance covered in low activity running',
#       'ZH': 'distance covered in low activity running',
#       'TR': 'Distance covered in low-activity running',
#       'HU': 'Distance covered in low-activity running',
#       'CS': 'Distance covered in low-activity running',
#       'NL': 'Distance covered in low-activity running'}},
#     'unit': 'KILOMETER',
#     'value': '12.75'},
#    {'attributes': {'DistanceMeters': '4849'},
#     'name': 'distance_covered_in_high_intensity_running',
#     'translations': {'name': {'EN': 'Distance covered in high-intensity running',
#       'FR': 'Distance parcourue à haute intensité',
#       'DE': 'Zurückgelegte Entfernung bei hochintensiven Läufen',
#       'ES': 'Distancia recorrida en carrera de alta intensidad',
#       'PT': 'Distância percorrida em corrida de alta intensidade',
#       'IT': 'Distanza percorsa in corsa ad alta intensità',
#       'RU': 'distance covered in high intensity running',
#       'ZH': 'distance covered in high intensity running',
#       'TR': 'Distance covered in high-intensity running',
#       'HU': 'Distance covered in high-intensity running',
#       'CS': 'Distance covered in high-intensity running',
#       'NL': 'Distance covered in high-intensity running'}},
#     'unit': 'KILOMETER',
#     'value': '4.84'},
#    {'attributes': {'DistanceMeters': '2031'},
#     'name': 'distance_covered_in_sprinting',
#     'translations': {'name': {'EN': 'Distance covered when sprinting',
#       'FR': 'Distance parcourue en sprint',
#       'DE': 'Zurückgelegte Entfernung im Sprint',
#       'ES': 'Distancia recorrida en esprint',
#       'PT': 'Distância percorrida a correr',
#       'IT': 'Distanza percorsa in scatto',
#       'RU': 'distance covered in sprinting',
#       'ZH': 'distance covered in sprinting',
#       'TR': 'Distance covered when sprinting',
#       'HU': 'Distance covered when sprinting',
#       'CS': 'Distance covered when sprinting',
#       'NL': 'Distance covered when sprinting'}},
#     'unit': 'KILOMETER',
#     'value': '2.03'},
#    {'attributes': {'TotalMinutesAndSeconds': '115\'44"',
#      'TotalSeconds': '6944'},
#     'name': 'time_spent_in_standing_activity',
#     'translations': {'name': {'EN': 'Time spent standing still',
#       'FR': 'Temps immobile',
#       'DE': 'Zeit im Stehen',
#       'ES': 'Tiempo estando de pie',
#       'PT': 'Tempo despendido em inactividade',
#       'IT': 'Tempo trascorso da fermo',
#       'RU': 'time spent in standing activity',
#       'ZH': 'time spent in standing activity',
#       'TR': 'Time spent standing still',
#       'HU': 'Time spent standing still',
#       'CS': 'Time spent standing still',
#       'NL': 'Time spent standing still'}},
#     'unit': 'MINUTE',
#     'value': '116'},
#    {'attributes': {'TotalMinutesAndSeconds': '581\'15"',
#      'TotalSeconds': '34874'},
#     'name': 'time_spent_in_walking_activity',
#     'translations': {'name': {'EN': 'Time spent walking',
#       'FR': 'Temps passé en marchant',
#       'DE': 'Zeit im Gehen',
#       'ES': 'Tiempo andando',
#       'PT': 'Tempo despendido a andar',
#       'IT': 'Tempo trascorso camminando',
#       'RU': 'time spent in walking activity',
#       'ZH': 'time spent in walking activity',
#       'TR': 'Time spent walking',
#       'HU': 'Time spent walking',
#       'CS': 'Time spent walking',
#       'NL': 'Time spent walking'}},
#     'unit': 'MINUTE',
#     'value': '582'},
#    {'attributes': {'TotalMinutesAndSeconds': '256\'16"',
#      'TotalSeconds': '15375'},
#     'name': 'time_spent_in_jogging_activity',
#     'translations': {'name': {'EN': 'Time spent jogging',
#       'FR': 'Temps passé à allure footing',
#       'DE': 'Gejoggte Laufzeit',
#       'ES': 'Tiempo en carrera de intensidad media',
#       'PT': 'Tempo despendido em corrida',
#       'IT': 'Tempo trascorso in corsa leggera',
#       'RU': 'time spent in jogging activity',
#       'ZH': 'time spent in jogging activity',
#       'TR': 'Time spent jogging',
#       'HU': 'Time spent jogging',
#       'CS': 'Time spent jogging',
#       'NL': 'Time spent jogging'}},
#     'unit': 'MINUTE',
#     'value': '257'},
#    {'attributes': {'TotalMinutesAndSeconds': '45\'01"',
#      'TotalSeconds': '2701'},
#     'name': 'time_spent_in_low_intensity_running',
#     'translations': {'name': {'EN': 'Time spent in low-intensity running',
#       'FR': 'Temps passé en courant à intensité modérée',
#       'DE': 'Laufzeit mit geringer Intensität',
#       'ES': 'Tiempo gastado en carrera de baja intensidad',
#       'PT': 'Tempo despendido em corrida lenta',
#       'IT': 'Tempo trascorso in corsa a bassa intensità',
#       'RU': 'time spent in low intensity running',
#       'ZH': 'time spent in low intensity running',
#       'TR': 'Time spent in low-intensity running',
#       'HU': 'Time spent in low-intensity running',
#       'CS': 'Time spent in low-intensity running',
#       'NL': 'Time spent in low-intensity running'}},
#     'unit': 'MINUTE',
#     'value': '46'},
#    {'attributes': {'TotalMinutesAndSeconds': '13\'13"', 'TotalSeconds': '793'},
#     'name': 'time_spent_in_high_activity_running',
#     'translations': {'name': {'EN': 'Time spent in high-activity running',
#       'FR': 'Temps passé dans des courses à haute intensité',
#       'DE': 'Intensive Laufzeit',
#       'ES': 'Tiempo en carreras de alta intensidad',
#       'PT': 'Tempo despendido em grande velocidade',
#       'IT': 'Tempo trascorso in corsa ad alta intensità',
#       'RU': 'time spent in high activity running',
#       'ZH': 'time spent in high activity running',
#       'TR': 'Time spent in high-activity running',
#       'HU': 'Time spent in high-activity running',
#       'CS': 'Time spent in high-activity running',
#       'NL': 'Time spent in high-activity running'}},
#     'unit': 'MINUTE',
#     'value': '14'},
#    {'attributes': {'TotalMinutesAndSeconds': '4\'26"', 'TotalSeconds': '266'},
#     'name': 'players_time_in_sprinting_activity',
#     'translations': {'name': {'EN': 'players time in sprinting activity',
#       'FR': 'players time in sprinting activity',
#       'DE': 'players time in sprinting activity',
#       'ES': 'tiempo de los jugadores en esprint',
#       'PT': 'tempo dos jogadores a correr',
#       'IT': 'players time in sprinting activity',
#       'RU': 'players time in sprinting activity',
#       'ZH': 'players time in sprinting activity',
#       'TR': 'players time in sprinting activity',
#       'HU': 'players time in sprinting activity',
#       'CS': 'players time in sprinting activity',
#       'NL': 'players time in sprinting activity'}},
#     'unit': 'MINUTE',
#     'value': '5'},
#    {'name': 'top_speed',
#     'translations': {'name': {'EN': 'Top speed (km/h)',
#       'FR': 'Vitesse maximale (km/h)',
#       'DE': 'Top-Speed  (km/h)',
#       'ES': 'Velocidad máxima (km/h)',
#       'PT': 'Velocidade máxima (km/h)',
#       'IT': 'Velocità massima (km/h)',
#       'RU': 'Максимальная скорость',
#       'ZH': 'top_speed',
#       'TR': 'Top speed (km/h)',
#       'HU': 'Top speed',
#       'CS': 'Top speed (km/h)',
#       'NL': 'Top speed'}},
#     'unit': 'KILOMETER_PER_HOUR',
#     'value': '34.3'},
#    {'name': 'sprints',
#     'translations': {'name': {'EN': 'Sprints',
#       'FR': 'Sprints',
#       'DE': 'Sprints',
#       'ES': 'Esprints',
#       'PT': 'Sprints',
#       'IT': 'Scatti',
#       'RU': 'Рывки',
#       'ZH': 'sprints',
#       'TR': 'Sprints',
#       'HU': 'Sprints',
#       'CS': 'Sprints',
#       'NL': 'Sprints'}},
#     'value': '131'},
#    {'name': 'sprints_average_no_gk',
#     'translations': {'name': {'EN': 'Average sprints per player (excluding goalkeeper)',
#       'FR': 'Moyennes de sprints (hors gardien ou gardienne)',
#       'DE': 'Durchschnittliche Sprints pro Spieler (exklusive Torhüter)',
#       'ES': 'Promedio de esprints por jugador (excluyendo al portero)',
#       'PT': 'Média de sprints por jogador (excluindo guarda-redes)',
#       'IT': 'Percentuale scatti per giocatore (portiere escluso)',
#       'RU': 'sprints average excluding gk',
#       'ZH': 'sprints average excluding gk',
#       'TR': 'Average sprints per player (excluding goalkeeper)',
#       'HU': 'Average sprints per player (excluding goalkeeper)',
#       'CS': 'Average sprints per player (excluding goalkeeper)',
#       'NL': 'Average sprints per player (excluding goalkeeper)'}},
#     'value': '8.73'},
#    {'attributes': {'DistanceMeters': '10351'},
#     'name': 'average_distance',
#     'translations': {'name': {'EN': 'Average distance covered (km)',
#       'FR': 'Distance moyenne (km)',
#       'DE': 'Zurückgelegte Distanz im Schnitt (km)',
#       'ES': 'Promedio de distancia recorrida (km)',
#       'PT': 'Média de distância percorrida (km)',
#       'IT': 'Media distanza coperta (km)',
#       'RU': 'Ср. дистанция (км)',
#       'ZH': 'Average distance',
#       'TR': 'Average distance covered (km)',
#       'HU': 'Average distance covered (km)',
#       'CS': 'Average distance covered (km)',
#       'NL': 'Average distance covered (km)'}},
#     'unit': 'KILOMETER',
#     'value': '10.35'},
#    {'attributes': {'DistanceMeters': '11985'},
#     'name': 'distance_covered_ball_not_in_play',
#     'translations': {'name': {'EN': 'Distance covered while ball not in play',
#       'FR': "Distance parcourue lorsque le ballon n'est pas en jeu",
#       'DE': 'Zurückgelegte Entfernung wenn der Ball nicht im Spiel war',
#       'ES': 'Distancia recorrida con el balón no en juego',
#       'PT': 'Distância percorrida enquanto a bola não está em jogo',
#       'IT': 'Distanza percorsa con il pallone non in gioco',
#       'RU': 'distance covered while ball not in play',
#       'ZH': 'distance covered while ball not in play',
#       'TR': 'Distance covered while ball not in play',
#       'HU': 'Distance covered while ball not in play',
#       'CS': 'Distance covered while ball not in play',
#       'NL': 'Distance covered while ball not in play'}},
#     'unit': 'KILOMETER',
#     'value': '11.98'},
#    {'attributes': {'DistanceMeters': '67721'},
#     'name': 'distance_covered_not_in_possession',
#     'translations': {'name': {'EN': 'distance covered not in possession',
#       'FR': 'distance parcourue sans le ballon',
#       'DE': 'distance covered not in possession',
#       'ES': 'distancia recorrida sin la posesión',
#       'PT': 'distância percorrida sem a bola',
#       'IT': 'distance covered not in possession',
#       'RU': 'дистанция без мяча',
#       'ZH': 'distance covered not in possession',
#       'TR': 'distance covered not in possession',
#       'HU': 'distance covered not in possession',
#       'CS': 'distance covered not in possession',
#       'NL': 'distance covered not in possession'}},
#     'unit': 'KILOMETER',
#     'value': '67.72'},
#    {'name': 'distance_covered_in_high_intensity_running_ratio',
#     'translations': {'name': {'EN': 'Ratio of distance covered in high-intensity running',
#       'FR': 'Taux de distance parcourue à haute intensité',
#       'DE': 'Verhältnis zur zurückgelegten Entfernung bei hochintensiven Läufen',
#       'ES': 'Ratio de distancia recorrida en carrera de alta intensidad',
#       'PT': 'Rácio de distância percorrida em corrida de alta intensidade',
#       'IT': 'Percentuale distanza percorsa in corsa ad alta intensità',
#       'RU': 'distance covered in high intensity running ratio',
#       'ZH': 'distance covered in high intensity running ratio',
#       'TR': 'Ratio of distance covered in high-intensity running',
#       'HU': 'Ratio of distance covered in high-intensity running',
#       'CS': 'Ratio of distance covered in high-intensity running',
#       'NL': 'Ratio of distance covered in high-intensity running'}},
#     'value': '0.0467733623706616'},
#    {'name': 'time_spent_standing_activity_ratio',
#     'translations': {'name': {'EN': 'Ratio of time spent standing',
#       'FR': 'Taux de temps passé presque immobile',
#       'DE': 'Verhältnis zur im Stehen verbrachten Zeit',
#       'ES': 'Ratio de tiempo estando de pie',
#       'PT': 'time spent in standing activity ratio',
#       'IT': 'Percentuale di tempo trascorso da fermo',
#       'RU': 'time spent in standing activity ratio',
#       'ZH': 'time spent in standing activity ratio',
#       'TR': 'Ratio of time spent standing',
#       'HU': 'Ratio of time spent standing',
#       'CS': 'Ratio of time spent standing',
#       'NL': 'Ratio of time spent standing'}},
#     'value': '0.11392644136531'},
#    {'name': 'time_spent_walking_activity_ratio',
#     'translations': {'name': {'EN': 'Ratio of time spent walking',
#       'FR': 'Taux de temps passé en marchant',
#       'DE': 'Verhältnis zur im Gehen verbrachten Zeit',
#       'ES': 'Ratio de tiempo andando',
#       'PT': 'Rácio de tempo passado a andar',
#       'IT': 'Percentuale di tempo trascorso camminando',
#       'RU': 'time spent in walking activity ratio',
#       'ZH': 'time spent in walking activity ratio',
#       'TR': 'Ratio of time spent walking',
#       'HU': 'Ratio of time spent walking',
#       'CS': 'Ratio of time spent walking',
#       'NL': 'Ratio of time spent walking'}},
#     'value': '0.572131876630842'},
#    {'name': 'time_spent_jogging_activity_ratio',
#     'translations': {'name': {'EN': 'Ratio of time spent when jogging',
#       'FR': 'Taux de temps passé en footing',
#       'DE': 'Verhältnis zur im Joggen verbrachten Zeit',
#       'ES': 'Ratio de tiempo en carrera de intensidad media',
#       'PT': 'Rácio de tempo despendido em corrida moderada',
#       'IT': 'Percentuale di tempo trascorso in corsa leggera',
#       'RU': 'time spent in jogging activity ratio',
#       'ZH': 'time spent in jogging activity ratio',
#       'TR': 'Ratio of time spent when jogging',
#       'HU': 'Ratio of time spent when jogging',
#       'CS': 'Ratio of time spent when jogging',
#       'NL': 'Ratio of time spent when jogging'}},
#     'value': '0.252249152906453'},
#    {'attributes': {'TotalSeconds': '60955'},
#     'name': 'total_time_spent_in_activity',
#     'translations': {'name': {'EN': 'total time spent in activity',
#       'FR': 'total time spent in activity',
#       'DE': 'total time spent in activity',
#       'ES': 'tiempo total en actividad',
#       'PT': 'tempo total passado em actividade',
#       'IT': 'total time spent in activity',
#       'RU': 'total time spent in activity',
#       'ZH': 'total time spent in activity',
#       'TR': 'total time spent in activity',
#       'HU': 'total time spent in activity',
#       'CS': 'total time spent in activity',
#       'NL': 'total time spent in activity'}},
#     'unit': 'MINUTE',
#     'value': '1016'},
#    {'name': 'time_spent_low_activity_running_ratio',
#     'translations': {'name': {'EN': 'time spent in low activity running ratio',
#       'FR': 'time spent in low activity running ratio',
#       'DE': 'time spent in low activity running ratio',
#       'ES': 'Ratio de tiempo en carrera de baja intensidad',
#       'PT': 'Rácio de tempo passado em corrida de baixa intensidade',
#       'IT': 'time spent in low activity running ratio',
#       'RU': 'time spent in low activity running ratio',
#       'ZH': 'time spent in low activity running ratio',
#       'TR': 'time spent in low activity running ratio',
#       'HU': 'time spent in low activity running ratio',
#       'CS': 'time spent in low activity running ratio',
#       'NL': 'time spent in low activity running ratio'}},
#     'value': '0.0443110014870533'},
#    {'name': 'time_spent_high_activity_running_ratio',
#     'translations': {'name': {'EN': 'time spent in high activity running ratio',
#       'FR': 'time spent in high activity running ratio',
#       'DE': 'time spent in high activity running ratio',
#       'ES': 'Ratio de tiempo en carrera de alta intensidad',
#       'PT': 'Rácio de tempo passado em corrida de alta intensidade',
#       'IT': 'time spent in high activity running ratio',
#       'RU': 'time spent in high activity running ratio',
#       'ZH': 'time spent in high activity running ratio',
#       'TR': 'time spent in high activity running ratio',
#       'HU': 'time spent in high activity running ratio',
#       'CS': 'time spent in high activity running ratio',
#       'NL': 'time spent in high activity running ratio'}},
#     'value': '0.0130176896260558'},
#    {'name': 'time_spent_sprinting_activity_ratio',
#     'translations': {'name': {'EN': 'Ratio of time spent sprinting',
#       'FR': 'Taux de temps passé en sprint',
#       'DE': 'Verhältnis zur im Sprint verbrachten Zeit',
#       'ES': 'Ratio de tiempo al esprint',
#       'PT': 'Rácio de tempo despendido a correr',
#       'IT': 'Percentuale di tempo trascorso scattando',
#       'RU': 'time spent in sprinting activity ratio',
#       'ZH': 'time spent in sprinting activity ratio',
#       'TR': 'Ratio of time spent sprinting',
#       'HU': 'Ratio of time spent sprinting',
#       'CS': 'Ratio of time spent sprinting',
#       'NL': 'Ratio of time spent sprinting'}},
#     'value': '0.00436383798428588'},
#    {'name': 'offsides_last_15',
#     'translations': {'name': {'EN': 'Offsides in last 15 minutes',
#       'FR': 'Hors-jeu dans les 15 dernières minutes',
#       'DE': 'Abseits in den letzten 15 Minuten',
#       'ES': 'Fueras de juego en los últimos 15 minutos',
#       'PT': 'Foras-de-jogo nos últimos 15 minutos',
#       'IT': 'Fuorigioco negli ultimi 15 minuti',
#       'RU': 'offsides in the last 15',
#       'ZH': 'offsides in the last 15',
#       'TR': 'Offsides in last 15 minutes',
#       'HU': 'Offsides in last 15 minutes',
#       'CS': 'Offsides in last 15 minutes',
#       'NL': 'Offsides in last 15 minutes'}},
#     'value': '0'},
#    {'name': 'fouls_committed_last_15',
#     'translations': {'name': {'EN': 'Fouls committed in last 15 minutes',
#       'FR': 'Fautes commises dans les 15 dernières minutes',
#       'DE': 'Begangene Fouls in den letzten 15 Minuten',
#       'ES': 'Faltas cometidas en los últimos 15 minutos',
#       'PT': 'Faltas cometidas nos últimos 15 minutos',
#       'IT': 'Falli commessi negli ultimi 15 minuti',
#       'RU': 'fouls committed in the last 15',
#       'ZH': 'fouls committed in the last 15',
#       'TR': 'Fouls committed in last 15 minutes',
#       'HU': 'Fouls committed in last 15 minutes',
#       'CS': 'Fouls committed in last 15 minutes',
#       'NL': 'Fouls committed in last 15 minutes'}},
#     'value': '9'},
#    {'name': 'yellow_cards_last_15',
#     'translations': {'name': {'EN': 'yellow cards during last 15',
#       'FR': 'yellow cards during last 15',
#       'DE': 'yellow cards during last 15',
#       'ES': 'tarjetas amarillas en los últimos 15',
#       'PT': 'cartões amarelos nos últimos 15',
#       'IT': 'yellow cards during last 15',
#       'RU': 'yellow cards during last 15',
#       'ZH': 'yellow cards during last 15',
#       'TR': 'yellow cards during last 15',
#       'HU': 'yellow cards during last 15',
#       'CS': 'yellow cards during last 15',
#       'NL': 'yellow cards during last 15'}},
#     'value': '1'},
#    {'name': 'red_cards_last_15',
#     'translations': {'name': {'EN': 'Red cards in last 15 minutes',
#       'FR': 'Cartons rouges dans les 15 dernières minutes',
#       'DE': 'Rote Karten in den letzten 15 Minuten',
#       'ES': 'Tarjetas rojas en los últimos 15 minutos',
#       'PT': 'Cartões vermelhos nos últimos 15 minutos',
#       'IT': 'Cartellini rossi negli ultimi 15 minuti',
#       'RU': 'Красные карточки в последние 15 минут',
#       'ZH': 'red cards in the last 15',
#       'TR': 'Red cards in last 15 minutes',
#       'HU': 'Red cards in last 15 minutes',
#       'CS': 'Red cards in last 15 minutes',
#       'NL': 'Red cards in last 15 minutes'}},
#     'value': '1'},
#    {'name': 'saves_last_15',
#     'translations': {'name': {'EN': 'Saves in the last 15 minutes',
#       'FR': 'Arrêts dans les 15 dernières minutes',
#       'DE': 'Paraden in den letzten 15 Minuten',
#       'ES': 'Paradas en los últimos 15 minutos',
#       'PT': 'Defesas nos últimos 15 minutos',
#       'IT': 'Salvataggi negli ultimi 15 minuti',
#       'RU': 'Сейвы в последние 15 минут',
#       'ZH': 'saves in the last 15',
#       'TR': 'Saves in the last 15 minutes',
#       'HU': 'Saves in the last 15 minutes',
#       'CS': 'Saves in the last 15 minutes',
#       'NL': 'Saves in the last 15 minutes'}},
#     'value': '5'},
#    {'name': 'corners_last_15',
#     'translations': {'name': {'EN': 'Corners in the last 15 minutes',
#       'FR': 'Corners dans les 15 dernières minutes',
#       'DE': 'Ecken in den letzten 15 Minuten',
#       'ES': 'Saques de esquina en los últimos 15 minutos',
#       'PT': 'Cantos nos últimos 15 minutos',
#       'IT': 'Corner negli ultimi 15 minuti',
#       'RU': 'Угловые за последние 15 минут',
#       'ZH': 'corners in the last 15 minutes',
#       'TR': 'Corners in the last 15 minutes',
#       'HU': 'Corners in the last 15 minutes',
#       'CS': 'Corners in the last 15 minutes',
#       'NL': 'Corners in the last 15 minutes'}},
#     'value': '0'},
#    {'name': 'blocks_last_15',
#     'translations': {'name': {'EN': 'Blocks in the last 15 minutes',
#       'FR': 'Contres dans les 15 dernières minutes',
#       'DE': 'Abgeblockte Bälle in den letzten 15 Minuten',
#       'ES': 'Bloqueos en los últimos 15 minutos',
#       'PT': 'Bloqueios nos últimos 15 minutos',
#       'IT': 'Blocchi negli ultimi 15 minuti',
#       'RU': 'Блокированные удары в последние 15 минут',
#       'ZH': 'blocks in the last 15 minutes',
#       'TR': 'Blocks in the last 15 minutes',
#       'HU': 'Blocks in the last 15 minutes',
#       'CS': 'Blocks in the last 15 minutes',
#       'NL': 'Blocks in the last 15 minutes'}},
#     'value': '5'},
#    {'name': 'assists_last_15',
#     'translations': {'name': {'EN': 'Assists in the last 15 minutes',
#       'FR': 'Passes décisives dans les quinze dernières minutes',
#       'DE': 'Assists in den letzten 15 Minuten',
#       'ES': 'Asistencias en los últimos 15 minutos',
#       'PT': 'Assistências nos últimos 15 minutos',
#       'IT': 'Assist negli ultimi 15 minuti',
#       'RU': 'Голевые пасы в последние 15 минут',
#       'ZH': 'assists in the last 15 minutes',
#       'TR': 'Assists in the last 15 minutes',
#       'HU': 'Assists in the last 15 minutes',
#       'CS': 'Assists in the last 15 minutes',
#       'NL': 'Assists in the last 15 minutes'}},
#     'value': '1'},
#    {'name': 'goalkeeper_kicks_last_15',
#     'translations': {'name': {'EN': 'goalkeeper kicks in the last 15',
#       'FR': 'goalkeeper kicks in the last 15',
#       'DE': 'goalkeeper kicks in the last 15',
#       'ES': 'Saques de puerta del portero en los últimos 15 minutos',
#       'PT': 'pontapés do guarda-redes nos últimos 15',
#       'IT': 'goalkeeper kicks in the last 15',
#       'RU': 'goalkeeper kicks in the last 15',
#       'ZH': 'goalkeeper kicks in the last 15',
#       'TR': 'goalkeeper kicks in the last 15',
#       'HU': 'goalkeeper kicks in the last 15',
#       'CS': 'goalkeeper kicks in the last 15',
#       'NL': 'goalkeeper kicks in the last 15'}},
#     'value': '10'},
#    {'name': 'free_kick_direct_last_15',
#     'translations': {'name': {'EN': 'Direct free-kicks in last 15 minutes',
#       'FR': 'Coups francs directs dans les 15 dernières minutes',
#       'DE': 'Direkte Freistöße in den letzten 15 Minuten',
#       'ES': 'Libres directos en los últimos 15 minutos',
#       'PT': 'Livres directos nos últimos 15 minutos',
#       'IT': 'Calci di punizione diretti negli ultimi 15 minuti',
#       'RU': 'direct free kick in the last 15',
#       'ZH': 'direct free kick in the last 15',
#       'TR': 'Direct free-kicks in last 15 minutes',
#       'HU': 'Direct free-kicks in last 15 minutes',
#       'CS': 'Direct free-kicks in last 15 minutes',
#       'NL': 'Direct free-kicks in last 15 minutes'}},
#     'value': '15'},
#    {'name': 'free_kick_indirect_last_15',
#     'translations': {'name': {'EN': 'Indirect free-kicks in last 15 minutes',
#       'FR': 'Coups francs directs dans les 15 dernières minutes',
#       'DE': 'Indirekte Freistöße in den letzten 15 Minuten',
#       'ES': 'Libres indirectos en los últimos 15 minutos',
#       'PT': 'Livres indirectos nos últimos 15 minutos',
#       'IT': 'Calci di punizione indiretti negli ultimi 15 minuti',
#       'RU': 'indirect free kick in the last 15',
#       'ZH': 'indirect free kick in the last 15',
#       'TR': 'Indirect free-kicks in last 15 minutes',
#       'HU': 'Indirect free-kicks in last 15 minutes',
#       'CS': 'Indirect free-kicks in last 15 minutes',
#       'NL': 'Indirect free-kicks in last 15 minutes'}},
#     'value': '4'},
#    {'attributes': {'Den': '10', 'Num': '5'},
#     'name': 'saves_over_shot_on_target_ratio',
#     'translations': {'name': {'EN': 'Ratio of saves to shots on target',
#       'FR': "Taux d'arrêts sur tirs cadrés",
#       'DE': 'Verhältnis von Paraden zu den Torschüssen',
#       'ES': 'Ratio de paradas y tiros a puerta',
#       'PT': 'Rácio de defesas de remates enquadrados',
#       'IT': 'Percentuale salvataggi/tiri nello specchio',
#       'RU': 'saves over shot on target ratio',
#       'ZH': 'saves over shot on target ratio',
#       'TR': 'Ratio of saves to shots on target',
#       'HU': 'Ratio of saves to shots on target',
#       'CS': 'Ratio of saves to shots on target',
#       'NL': 'Ratio of saves to shots on target'}},
#     'value': '50'},
#    {'name': 'seasonal_total_saves',
#     'translations': {'name': {'EN': 'seasonal total saves',
#       'FR': 'seasonal total saves',
#       'DE': 'seasonal total saves',
#       'ES': 'Paradas totales en temporada',
#       'PT': 'total de defesas na temporada',
#       'IT': 'seasonal total saves',
#       'RU': 'seasonal total saves',
#       'ZH': 'seasonal total saves',
#       'TR': 'seasonal total saves',
#       'HU': 'seasonal total saves',
#       'CS': 'seasonal total saves',
#       'NL': 'seasonal total saves'}},
#     'value': '5'},
#    {'name': 'seasonal_total_blocks',
#     'translations': {'name': {'EN': 'seasonal total blocks',
#       'FR': 'seasonal total blocks',
#       'DE': 'seasonal total blocks',
#       'ES': 'Bloqueos totales en temporada',
#       'PT': 'total de intercepções na temporada',
#       'IT': 'seasonal total blocks',
#       'RU': 'seasonal total blocks',
#       'ZH': 'seasonal total blocks',
#       'TR': 'seasonal total blocks',
#       'HU': 'seasonal total blocks',
#       'CS': 'seasonal total blocks',
#       'NL': 'seasonal total blocks'}},
#     'value': '5'},
#    {'name': 'seasonal_assists',
#     'translations': {'name': {'EN': 'seasonal assists',
#       'FR': 'seasonal assists',
#       'DE': 'seasonal assists',
#       'ES': 'Asistencias de temporada',
#       'PT': 'assistências na temporada',
#       'IT': 'seasonal assists',
#       'RU': 'seasonal assists',
#       'ZH': 'seasonal assists',
#       'TR': 'seasonal assists',
#       'HU': 'seasonal assists',
#       'CS': 'seasonal assists',
#       'NL': 'seasonal assists'}},
#     'value': '1'},
#    {'name': 'dribbling',
#     'translations': {'name': {'EN': 'Dribbles',
#       'FR': 'Dribbles',
#       'DE': 'Dribblings',
#       'ES': 'Regates',
#       'PT': 'Dribles',
#       'IT': 'Dribbling',
#       'RU': 'Обводки',
#       'ZH': 'dribbling',
#       'TR': 'Dribbles',
#       'HU': 'Dribbles',
#       'CS': 'Dribbles',
#       'NL': 'Dribbles'}},
#     'value': '6'},
#    {'name': 'goals',
#     'translations': {'name': {'EN': 'Goals',
#       'FR': 'Buts',
#       'DE': 'Tore',
#       'ES': 'Goles',
#       'PT': 'Golos',
#       'IT': 'Gol',
#       'RU': 'Голы',
#       'ZH': 'goals',
#       'TR': 'Goals',
#       'HU': 'Goals',
#       'CS': 'Goals',
#       'NL': 'Goals'}},
#     'value': '1'},
#    {'name': 'attempts',
#     'translations': {'name': {'EN': 'Total attempts',
#       'FR': 'Tirs',
#       'DE': 'Abschlüsse gesamt',
#       'ES': 'Disparos totales',
#       'PT': 'Total de remates',
#       'IT': 'Tiri totali',
#       'RU': 'Всего ударов',
#       'ZH': 'attempts',
#       'TR': 'Total attempts',
#       'HU': 'Total attempts',
#       'CS': 'Total attempts',
#       'NL': 'Total attempts'}},
#     'value': '1'},
#    {'name': 'attempts_on_target',
#     'translations': {'name': {'EN': 'Attempts on target',
#       'FR': 'Tirs cadrés',
#       'DE': 'Abschlüsse aufs Tor',
#       'ES': 'Disparos a puerta',
#       'PT': 'Remates enquadrados',
#       'IT': 'Tiri nello specchio',
#       'RU': 'В створ',
#       'ZH': 'attempts_on_target',
#       'TR': 'Attempts on target',
#       'HU': 'On target',
#       'CS': 'Attempts on target',
#       'NL': 'On target'}},
#     'value': '0'},
#    {'name': 'goals_conceded',
#     'translations': {'name': {'EN': 'Goals conceded',
#       'FR': 'Buts concédés',
#       'DE': 'Gegentore',
#       'ES': 'Goles encajados',
#       'PT': 'Golos sofridos',
#       'IT': 'Gol subiti',
#       'RU': 'Пропущенные голы',
#       'ZH': 'goals_conceded',
#       'TR': 'Goals conceded',
#       'HU': 'Goals conceded',
#       'CS': 'Goals conceded',
#       'NL': 'Goals conceded'}},
#     'value': '5'},
#    {'name': 'cross_attempted',
#     'translations': {'name': {'EN': 'Crosses attempted',
#       'FR': 'Centres tentés',
#       'DE': 'Flankenversuche',
#       'ES': 'Centros realizados',
#       'PT': 'Tentativa de cruzamentos',
#       'IT': 'Cross tentati',
#       'RU': 'Всего навесов/прострелов',
#       'ZH': 'cross_attempted',
#       'TR': 'Crosses attempted',
#       'HU': 'Crosses attempted',
#       'CS': 'Crosses attempted',
#       'NL': 'Crosses attempted'}},
#     'value': '5'},
#    {'name': 'throw_ins',
#     'translations': {'name': {'EN': 'Throw-ins',
#       'FR': 'Touches',
#       'DE': 'Einwürfe',
#       'ES': 'Saques de banda',
#       'PT': 'Lançamentos',
#       'IT': 'Rimesse laterali',
#       'RU': 'Вбрасывания',
#       'ZH': 'throw-in',
#       'TR': 'Throw-ins',
#       'HU': 'Throw-ins',
#       'CS': 'Throw-ins',
#       'NL': 'Throw-ins'}},
#     'value': '24'},
#    {'name': 'throw_ins_completed',
#     'translations': {'name': {'EN': 'Throw-ins completed',
#       'FR': 'Touches effectuées',
#       'DE': 'Angekommene Einwürfe',
#       'ES': 'Saques de banda completados',
#       'PT': 'Lançamentos de linha lateral efectuados',
#       'IT': 'Rimesse laterali completate',
#       'RU': 'throw-in completed',
#       'ZH': 'throw-in completed',
#       'TR': 'Throw-ins completed',
#       'HU': 'Throw-ins completed',
#       'CS': 'Throw-ins completed',
#       'NL': 'Throw-ins completed'}},
#     'value': '4'},
#    {'attributes': {'Den': '257', 'Num': '198'},
#     'name': 'passes_accuracy',
#     'translations': {'name': {'EN': 'Passing accuracy (%)',
#       'FR': 'Précision des passes (%)',
#       'DE': 'Passgenauigkeit (%)',
#       'ES': 'Precisión en el pase (%)',
#       'PT': 'Eficácia de passe (%)',
#       'IT': 'Precisione passaggi (%)',
#       'RU': 'Точность пасов',
#       'ZH': 'passes_accuracy',
#       'TR': 'Passing accuracy (%)',
#       'HU': 'Passing accuracy',
#       'CS': 'Passing accuracy (%)',
#       'NL': 'Passing accuracy'}},
#     'value': '77'},
#    {'name': 'penalty_scored',
#     'translations': {'name': {'EN': 'Penalties scored',
#       'FR': 'Penalties marqués',
#       'DE': 'Verwandelte Elfmeter',
#       'ES': 'Penaltis marcados',
#       'PT': 'Pénaltis convertidos',
#       'IT': 'Rigori segnati',
#       'RU': 'Забитые пенальти',
#       'ZH': 'penalty_scored',
#       'TR': 'Penalties scored',
#       'HU': 'Penalties scored',
#       'CS': 'Penalties scored',
#       'NL': 'Penalties scored'}},
#     'value': '0'},
#    {'name': 'passes_attempted',
#     'translations': {'name': {'EN': 'Passes attempted',
#       'FR': 'Passes tentées',
#       'DE': 'Versuchte Pässe',
#       'ES': 'Pases realizados',
#       'PT': 'Passes tentados',
#       'IT': 'Passaggi tentati',
#       'RU': 'Всего пасов',
#       'ZH': 'passes_attempted',
#       'TR': 'Passes attempted',
#       'HU': 'Passes attempted',
#       'CS': 'Passes attempted',
#       'NL': 'Passes attempted'}},
#     'value': '257'},
#    {'name': 'goals_scored',
#     'translations': {'name': {'EN': 'Goals scored',
#       'FR': 'Buts marqués',
#       'DE': 'Erzielte Tore',
#       'ES': 'Goles marcados',
#       'PT': 'Golos marcados',
#       'IT': 'Gol segnati',
#       'RU': 'Забитые голы',
#       'ZH': 'goals_scored',
#       'TR': 'Goals scored',
#       'HU': 'Goals scored',
#       'CS': 'Goals scored',
#       'NL': 'Goals scored'}},
#     'value': '0'},
#    {'name': 'offsides',
#     'translations': {'name': {'EN': 'Offsides',
#       'FR': 'Hors-jeu',
#       'DE': 'Abseits',
#       'ES': 'Fueras de juego',
#       'PT': 'Foras-de-jogo',
#       'IT': 'Fuorigioco',
#       'RU': 'Офсайды',
#       'ZH': 'offsides',
#       'TR': 'Offsides',
#       'HU': 'Offsides',
#       'CS': 'Offsides',
#       'NL': 'Offsides'}},
#     'value': '0'},
#    {'name': 'fouls_committed_in_defensive_third',
#     'translations': {'name': {'EN': 'Fouls committed in defensive third',
#       'FR': 'Fautes commises dans ses 30 derniers mètres',
#       'DE': 'Im Verteidigungsdrittel begangene Fouls',
#       'ES': 'Faltas cometidas en el tercio defensivo',
#       'PT': 'Faltas cometidas no último terço defensivo',
#       'IT': 'Falli commessi nel terzo difensivo',
#       'RU': 'В зоне защиты',
#       'ZH': 'fouls_committed_in_defensive_third',
#       'TR': 'Fouls committed in defensive third',
#       'HU': 'Fouls committed in defensive third',
#       'CS': 'Fouls committed in defensive third',
#       'NL': 'Fouls committed in defensive third'}},
#     'value': '3'},
#    {'name': 'fouls_committed',
#     'translations': {'name': {'EN': 'Fouls committed',
#       'FR': 'Fautes commises',
#       'DE': 'Begangene Fouls',
#       'ES': 'Faltas cometidas',
#       'PT': 'Faltas cometidas',
#       'IT': 'Falli commessi',
#       'RU': 'Фолы',
#       'ZH': 'fouls_committed',
#       'TR': 'Fouls committed',
#       'HU': 'Fouls committed',
#       'CS': 'Fouls committed',
#       'NL': 'Fouls committed'}},
#     'value': '9'},
#    {'name': 'fouls_suffered',
#     'translations': {'name': {'EN': 'Fouls suffered',
#       'FR': 'Fautes obtenues',
#       'DE': 'Gefoult worden',
#       'ES': 'Faltas sufridas',
#       'PT': 'Faltas sofridas',
#       'IT': 'Falli subiti',
#       'RU': 'Фолы соперников',
#       'ZH': 'fouls_suffered',
#       'TR': 'Fouls suffered',
#       'HU': 'Fouls suffered',
#       'CS': 'Fouls suffered',
#       'NL': 'Fouls suffered'}},
#     'value': '14'},
#    {'name': 'yellow_cards',
#     'translations': {'name': {'EN': 'Yellow cards',
#       'FR': 'Cartons jaunes',
#       'DE': 'Gelbe Karten',
#       'ES': 'Tarjetas amarillas',
#       'PT': 'Cartões amarelos',
#       'IT': 'Cartellini gialli',
#       'RU': 'Желтые карточки',
#       'ZH': 'yellow_cards',
#       'TR': 'Yellow cards',
#       'HU': 'Yellow cards',
#       'CS': 'Yellow cards',
#       'NL': 'Yellow cards'}},
#     'value': '1'},
#    {'name': 'red_cards',
#     'translations': {'name': {'EN': 'Red cards',
#       'FR': 'Cartons rouges',
#       'DE': 'Rote Karten',
#       'ES': 'Tarjetas rojas',
#       'PT': 'Cartões vermelhos',
#       'IT': 'Cartellini rossi',
#       'RU': 'Красные карточки',
#       'ZH': 'red_cards',
#       'TR': 'Red cards',
#       'HU': 'Red cards',
#       'CS': 'Red cards',
#       'NL': 'Red cards'}},
#     'value': '1'},
#    {'name': 'saves',
#     'translations': {'name': {'EN': 'Saves',
#       'FR': 'Arrêts',
#       'DE': 'Paraden',
#       'ES': 'Paradas',
#       'PT': 'Defesas',
#       'IT': 'Parate',
#       'RU': 'Сейвы',
#       'ZH': 'saves',
#       'TR': 'Saves',
#       'HU': 'Saves',
#       'CS': 'Saves',
#       'NL': 'Saves'}},
#     'value': '5'},
#    {'name': 'corners',
#     'translations': {'name': {'EN': 'Corners taken',
#       'FR': 'Corners tirés',
#       'DE': 'Ecken',
#       'ES': 'Saques de esquina sacados',
#       'PT': 'Cantos a favor',
#       'IT': 'Corner battuti',
#       'RU': 'Угловые',
#       'ZH': 'corners',
#       'TR': 'Corners taken',
#       'HU': 'Corners',
#       'CS': 'Corners taken',
#       'NL': 'Corners'}},
#     'value': '0'},
#    {'attributes': {'Fractional': '0.316', 'TotalSeconds': '1017'},
#     'name': 'ball_possession',
#     'translations': {'name': {'EN': 'Possession (%)',
#       'FR': 'Possession (%)',
#       'DE': 'Ballbesitz (%)',
#       'ES': 'Posesión (%)',
#       'PT': 'Posse de bola (%)',
#       'IT': 'Possesso palla (%)',
#       'RU': 'Владение',
#       'ZH': 'ball_possession',
#       'TR': 'Possession (%)',
#       'HU': 'Possession',
#       'CS': 'Possession (%)',
#       'NL': 'Possession'}},
#     'value': '32'},
#    {'name': 'attempts_off_target',
#     'translations': {'name': {'EN': 'Attempts off target',
#       'FR': 'Tirs non cadrés',
#       'DE': 'Abschlüsse nicht aufs Tor',
#       'ES': 'Disparos fuera',
#       'PT': 'Remates para fora',
#       'IT': 'Tiri fuori',
#       'RU': 'Мимо',
#       'ZH': 'attempts_off_target',
#       'TR': 'Attempts off target',
#       'HU': 'Off target',
#       'CS': 'Attempts off target',
#       'NL': 'Off target'}},
#     'value': '1'},
#    {'attributes': {'Den': '1', 'Num': '0'},
#     'name': 'attempts_accuracy',
#     'translations': {'name': {'EN': 'Shot accuracy',
#       'FR': 'Précision des tirs',
#       'DE': 'Schussgenauigkeit',
#       'ES': 'Precisión en el tiro',
#       'PT': 'Eficácia de remate',
#       'IT': 'Precisione di tiro',
#       'RU': 'Точность ударов',
#       'ZH': 'attempts accuracy',
#       'TR': 'Shot accuracy',
#       'HU': 'Shot accuracy',
#       'CS': 'Shot accuracy',
#       'NL': 'Shot accuracy'}},
#     'value': '0'},
#    {'name': 'penalties',
#     'translations': {'name': {'EN': 'penalties',
#       'FR': 'penalties',
#       'DE': 'penalties',
#       'ES': 'penaltis',
#       'PT': 'penáltis',
#       'IT': 'penalties',
#       'RU': 'penalties',
#       'ZH': 'penalties',
#       'TR': 'penalties',
#       'HU': 'penalties',
#       'CS': 'penalties',
#       'NL': 'penalties'}},
#     'value': '0'},
#    {'name': 'free_kicks_on_goal',
#     'translations': {'name': {'EN': 'Free-kicks on goal',
#       'FR': 'Coups francs cadrés',
#       'DE': 'Freistöße aufs Tor',
#       'ES': 'Libres directos a portería',
#       'PT': 'Livres à baliza',
#       'IT': 'Calci di punizione a rete',
#       'RU': 'free kicks on goal',
#       'ZH': 'free kicks on goal',
#       'TR': 'Free-kicks on goal',
#       'HU': 'Free-kicks on goal',
#       'CS': 'Free-kicks on goal',
#       'NL': 'Free-kicks on goal'}},
#     'value': '0'},
#    {'name': 'attempts_from_set_pieces',
#     'translations': {'name': {'EN': 'Attempts from set pieces',
#       'FR': 'Tirs sur des coups de pieds arrêtés',
#       'DE': 'Versuche nach Standardsituationen',
#       'ES': 'Ocasiones a balón parado',
#       'PT': 'Oportunidades de bolas paradas',
#       'IT': 'Conclusioni su palla inattiva',
#       'RU': 'attempts on set pieces',
#       'ZH': 'attempts on set pieces',
#       'TR': 'Attempts from set pieces',
#       'HU': 'Attempts from set pieces',
#       'CS': 'Attempts from set pieces',
#       'NL': 'Attempts from set pieces'}},
#     'value': '0'},
#    {'name': 'attempts_in_open_play',
#     'translations': {'name': {'EN': 'Attempts in open play',
#       'FR': 'Tirs dans le jeu',
#       'DE': 'Versuche aus dem Spiel heraus',
#       'ES': 'Ocasiones tras jugada',
#       'PT': 'Oportunidades em jogo corrido',
#       'IT': 'Conclusioni su azione',
#       'RU': 'attempts on open_play',
#       'ZH': 'attempts on open_play',
#       'TR': 'Attempts in open play',
#       'HU': 'Attempts in open play',
#       'CS': 'Attempts in open play',
#       'NL': 'Attempts in open play'}},
#     'value': '1'},
#    {'name': 'blocked',
#     'translations': {'name': {'EN': 'Blocks',
#       'FR': 'Attaques stoppées',
#       'DE': 'Geblockt',
#       'ES': 'Disparos bloqueados',
#       'PT': 'Intercepções',
#       'IT': 'Ribattute',
#       'RU': 'Блокированные удары',
#       'ZH': 'blocked',
#       'TR': 'Blocks',
#       'HU': 'Blocks',
#       'CS': 'Blocks',
#       'NL': 'Blocks'}},
#     'value': '5'},
#    {'name': 'total_attempts_against_from_set_pieces',
#     'translations': {'name': {'EN': 'Total attempts conceded from set pieces',
#       'FR': 'Tirs concédés sur des coups de pied arrêtés',
#       'DE': 'Zugelassene Versuche nach Standardsituationen',
#       'ES': 'Ocasiones totales concedidas tras balón parado',
#       'PT': 'Total de oportunidades concedidas de bolas paradas',
#       'IT': 'Totale conclusioni subite su palla inattiva',
#       'RU': 'total attempts conceded from set pieces',
#       'ZH': 'total attempts conceded from set pieces',
#       'TR': 'Total attempts conceded from set pieces',
#       'HU': 'Total attempts conceded from set pieces',
#       'CS': 'Total attempts conceded from set pieces',
#       'NL': 'Total attempts conceded from set pieces'}},
#     'value': '1'},
#    {'name': 'attempts_off_target_conceded',
#     'translations': {'name': {'EN': 'Attempts conceded off target',
#       'FR': 'Tirs non cadrés concédés',
#       'DE': 'Gegnerische Versuche neben das Tor',
#       'ES': 'Disparos fuera concedidos',
#       'PT': 'Remates contra para fora',
#       'IT': 'Tiri fuori subiti',
#       'RU': 'Мимо',
#       'ZH': 'attempts_off_target_conceded',
#       'TR': 'Attempts conceded off target',
#       'HU': 'Off target',
#       'CS': 'Attempts conceded off target',
#       'NL': 'Off target'}},
#     'value': '5'},
#    {'name': 'passes_short_attempted',
#     'translations': {'name': {'EN': 'Short passes attempted',
#       'FR': 'Passes courtes tentées',
#       'DE': 'Versuchte Kurzpässe',
#       'ES': 'Pases en corto realizados',
#       'PT': 'Passes curtos tentados',
#       'IT': 'Passaggi corti tentati',
#       'RU': 'Всего коротких пасов',
#       'ZH': 'passes_short_attempted',
#       'TR': 'Short passes attempted',
#       'HU': 'Short passes attempted',
#       'CS': 'Short passes attempted',
#       'NL': 'Short passes attempted'}},
#     'value': '82'},
#    {'name': 'passes_medium_attempted',
#     'translations': {'name': {'EN': 'Medium passes attempted',
#       'FR': 'Passes mi-longues tentées',
#       'DE': 'Versuche von mittelweiten Pässen',
#       'ES': 'Pases de media distancia realizados',
#       'PT': 'Média de passes tentados',
#       'IT': 'Passaggi media distanza tentati',
#       'RU': 'Всего средних пасов',
#       'ZH': 'passes_medium_attempted',
#       'TR': 'Medium passes attempted',
#       'HU': 'Medium passes attempted',
#       'CS': 'Medium passes attempted',
#       'NL': 'Medium passes attempted'}},
#     'value': '123'},
#    {'name': 'passes_long_attempted',
#     'translations': {'name': {'EN': 'Long passes attempted',
#       'FR': 'Passes longues tentées',
#       'DE': 'Versuche von weiten Pässen',
#       'ES': 'Pases en largo realizados',
#       'PT': 'Passes longos tentados',
#       'IT': 'Lanci lunghi tentati',
#       'RU': 'Всего длинных пасов',
#       'ZH': 'passes_long_attempted',
#       'TR': 'Long passes attempted',
#       'HU': 'Long passes attempted',
#       'CS': 'Long passes attempted',
#       'NL': 'Long passes attempted'}},
#     'value': '52'},
#    {'name': 'passes_short_completed',
#     'translations': {'name': {'EN': 'Short passes completed',
#       'FR': 'Passes courtes réussies',
#       'DE': 'Angekommene Kurzpässe',
#       'ES': 'Pases en corto completados',
#       'PT': 'Passes curtos bem sucedidos',
#       'IT': 'Passaggi corti completati',
#       'RU': 'Точные короткие пасы',
#       'ZH': 'passes_short_completed',
#       'TR': 'Short passes completed',
#       'HU': 'Short passes completed',
#       'CS': 'Short passes completed',
#       'NL': 'Short passes completed'}},
#     'value': '66'},
#    {'attributes': {'Den': '82', 'Num': '66'},
#     'name': 'passes_short_accuracy',
#     'translations': {'name': {'EN': 'Accuracy of short passes',
#       'FR': 'Précision des passes courtes',
#       'DE': 'Genauigkeit bei Kurzpässen',
#       'ES': 'Precisión en pases en corto',
#       'PT': 'Eficácia de passes curtos',
#       'IT': 'Accuratezza passaggi corti',
#       'RU': 'Точность коротких пасов',
#       'ZH': 'short passes accuracy',
#       'TR': 'Accuracy of short passes',
#       'HU': 'Accuracy of short passes',
# ...
#       'CS': 'Medium passes attempted (excluding goalkeeper)',
#       'NL': 'Medium passes attempted (excluding goalkeeper)'}},
#     'value': '426'},
#    {'name': 'passes_long_attempted_no_gk',
#     'translations': {'name': {'EN': 'Long passes attempted (excluding goalkeeper)',
#       'FR': 'Longue passes tentées (sauf gardien ou gardienne)',
#       'DE': 'Versuch langer Pässe (ohne Torhüter)',
#       'ES': 'Pases en largo realizados (excluyendo al portero)',
#       'PT': 'Passes longos tentados (excluindo guarda-redes)',
#       'IT': 'Passaggi lunghi tentati (escluso portiere)',
#       'RU': 'long passes attempted excluding gk',
#       'ZH': 'long passes attempted excluding gk',
#       'TR': 'Long passes attempted (excluding goalkeeper)',
#       'HU': 'Long passes attempted (excluding goalkeeper)',
#       'CS': 'Long passes attempted (excluding goalkeeper)',
#       'NL': 'Long passes attempted (excluding goalkeeper)'}},
#     'value': '39'},
#    {'name': 'passes_short_completed_no_gk',
#     'translations': {'name': {'EN': 'Short passes completed (excluding goalkeeper)',
#       'FR': 'Passes courtes réussies (sauf gardien ou gardienne)',
#       'DE': 'Erfolgreiche Kurzpässe (ohne Torhüter)',
#       'ES': 'Pases en corto completados (excluyendo al portero)',
#       'PT': 'Passes curtos completados (excluindo guarda-redes)',
#       'IT': 'Passaggi corti completati (escluso portiere)',
#       'RU': 'short passes completed excluding gk',
#       'ZH': 'short passes completed excluding gk',
#       'TR': 'Short passes completed (excluding goalkeeper)',
#       'HU': 'Short passes completed (excluding goalkeeper)',
#       'CS': 'Short passes completed (excluding goalkeeper)',
#       'NL': 'Short passes completed (excluding goalkeeper)'}},
#     'value': '207'},
#    {'name': 'passes_medium_completed_no_gk',
#     'translations': {'name': {'EN': 'Medium passes completed (excluding goalkeeper)',
#       'FR': 'Passes à moyenne distance réussies (sauf gardien ou gardienne)',
#       'DE': 'Erfolgreiche mittellange Pässe (ohne Torhüter)',
#       'ES': 'Pases medios completados (excluyendo al portero)',
#       'PT': 'Passes de média-distância completados (excluindo guarda-redes)',
#       'IT': 'Passaggi medi completati (escluso portiere)',
#       'RU': 'medium passes completed excluding gk',
#       'ZH': 'medium passes completed excluding gk',
#       'TR': 'Medium passes completed (excluding goalkeeper)',
#       'HU': 'Medium passes completed (excluding goalkeeper)',
#       'CS': 'Medium passes completed (excluding goalkeeper)',
#       'NL': 'Medium passes completed (excluding goalkeeper)'}},
#     'value': '405'},
#    {'name': 'passes_long_completed_no_gk',
#     'translations': {'name': {'EN': 'Long passes completed (excluding goalkeeper)',
#       'FR': 'Longue passes réussies (sauf gardien ou gardienne)',
#       'DE': 'Erfolgreiche lange Pässe (ohne Torhüter)',
#       'ES': 'Pases en largo completados (excluyendo al portero)',
#       'PT': 'Passes longos completados (excluindo guarda-redes)',
#       'IT': 'Passaggi lunghi completati (escluso portiere)',
#       'RU': 'long passes completed excluding gk',
#       'ZH': 'long passes completed excluding gk',
#       'TR': 'Long passes completed (excluding goalkeeper)',
#       'HU': 'Long passes completed (excluding goalkeeper)',
#       'CS': 'Long passes completed (excluding goalkeeper)',
#       'NL': 'Long passes completed (excluding goalkeeper)'}},
#     'value': '31'},
#    {'name': 'passes_completed_no_gk',
#     'translations': {'name': {'EN': 'Passes completed (excluding goalkeeper)',
#       'FR': 'Passes réussies (sauf gardien ou gardienne)',
#       'DE': 'Erfolgreiche Pässe (ohne Torhüter)',
#       'ES': 'Pases completados (excluyendo al portero)',
#       'PT': 'Passes completados (excluindo guarda-redes)',
#       'IT': 'Passaggi completati (portiere escluso)',
#       'RU': 'passes completed excluding gk',
#       'ZH': 'passes completed excluding gk',
#       'TR': 'Passes completed (excluding goalkeeper)',
#       'HU': 'Passes completed (excluding goalkeeper)',
#       'CS': 'Passes completed (excluding goalkeeper)',
#       'NL': 'Passes completed (excluding goalkeeper)'}},
#     'value': '643'},
#    {'name': 'key_passes',
#     'translations': {'name': {'EN': 'Key passes',
#       'FR': 'Passes clés',
#       'DE': 'Wichtige Pässe',
#       'ES': 'Pases clave',
#       'PT': 'Passes decisivos',
#       'IT': 'Passaggi chiave',
#       'RU': 'key passes',
#       'ZH': 'key passes',
#       'TR': 'Key passes',
#       'HU': 'Key passes',
#       'CS': 'Key passes',
#       'NL': 'Key passes'}},
#     'value': '17'},
#    {'name': 'crosses_attempted_left',
#     'translations': {'name': {'EN': 'Crosses attempted from the left',
#       'FR': 'Centres tentés de la gauche',
#       'DE': 'Versuchte Linksflanken',
#       'ES': 'Centros realizados desde la izquierda',
#       'PT': 'Cruzamentos tentados a partir da esquerda',
#       'IT': 'Cross tentati da sinistra',
#       'RU': 'left crosses attempted',
#       'ZH': 'left crosses attempted',
#       'TR': 'Crosses attempted from the left',
#       'HU': 'Crosses attempted from the left',
#       'CS': 'Crosses attempted from the left',
#       'NL': 'Crosses attempted from the left'}},
#     'value': '13'},
#    {'name': 'crosses_attempted_right',
#     'translations': {'name': {'EN': 'Crosses attempted from the right',
#       'FR': 'Centres tentés de la droite',
#       'DE': 'Versuchte Rechtsflanken',
#       'ES': 'Centros realizados desde la derecha',
#       'PT': 'Cruzamentos tentados a partir da direita',
#       'IT': 'Cross tentati da destra',
#       'RU': 'right crosses attempted',
#       'ZH': 'right crosses attempted',
#       'TR': 'Crosses attempted from the right',
#       'HU': 'Crosses attempted from the right',
#       'CS': 'Crosses attempted from the right',
#       'NL': 'Crosses attempted from the right'}},
#     'value': '9'},
#    {'name': 'throw_ins_into_attacking_third',
#     'translations': {'name': {'EN': 'Throw-ins into attacking third',
#       'FR': 'Touches dans les 30 derniers mètres',
#       'DE': 'Einwürfe ins Angriffsdrittel',
#       'ES': 'Saques de banda en el tercio ofensivo',
#       'PT': 'Lançamentos para o último terço',
#       'IT': 'Rimesse laterali sulla tre quarti offensiva',
#       'RU': 'Вбрасывания в зону атаки',
#       'ZH': 'throw-in into attacking third',
#       'TR': 'Throw-ins into attacking third',
#       'HU': 'Throw-ins into attacking third',
#       'CS': 'Throw-ins into attacking third',
#       'NL': 'Throw-ins into attacking third'}},
#     'value': '4'},
#    {'name': 'one_touch_play',
#     'translations': {'name': {'EN': 'one touch play',
#       'FR': 'one touch play',
#       'DE': 'one touch play',
#       'ES': 'Jugadas al primer toque',
#       'PT': 'jogadas ao primeiro toque',
#       'IT': 'one touch play',
#       'RU': 'one touch play',
#       'ZH': 'one touch play',
#       'TR': 'one touch play',
#       'HU': 'one touch play',
#       'CS': 'one touch play',
#       'NL': 'one touch play'}},
#     'value': '186'},
#    {'attributes': {'Den': '25', 'Num': '5'},
#     'name': 'goals_over_attempts_ratio',
#     'translations': {'name': {'EN': 'Ratio of goals to attempts',
#       'FR': 'Taux de buts par rapport aux tirs',
#       'DE': 'Verhältnis von Toren zu Schüssen',
#       'ES': 'Ratio de goles y ocasiones',
#       'PT': 'Rácio de golos por remate',
#       'IT': 'Percentuale gol/conclusioni',
#       'RU': 'goals over attempts ratio',
#       'ZH': 'goals over attempts ratio',
#       'TR': 'Ratio of goals to attempts',
#       'HU': 'Ratio of goals to attempts',
#       'CS': 'Ratio of goals to attempts',
#       'NL': 'Ratio of goals to attempts'}},
#     'value': '20'},
#    {'name': 'shot_in_goal_gate_inner_upper_left',
#     'translations': {'name': {'EN': 'shot in goal gate inner upper left',
#       'FR': 'shot in goal gate inner upper left',
#       'DE': 'shot in goal gate inner upper left',
#       'ES': 'shot in goal gate inner upper left',
#       'PT': 'remate superior à esquerda da baliza dentro da área',
#       'IT': 'shot in goal gate inner upper left',
#       'RU': 'shot in goal gate inner upper left',
#       'ZH': 'shot in goal gate inner upper left',
#       'TR': 'shot in goal gate inner upper left',
#       'HU': 'shot in goal gate inner upper left',
#       'CS': 'shot in goal gate inner upper left',
#       'NL': 'shot in goal gate inner upper left'}},
#     'value': '1'},
#    {'name': 'shot_in_goal_gate_inner_upper_center',
#     'translations': {'name': {'EN': 'shot in goal gate inner upper center',
#       'FR': 'shot in goal gate inner upper center',
#       'DE': 'shot in goal gate inner upper center',
#       'ES': 'tiro a puerta a la parte superior central',
#       'PT': 'remate superior ao centro da baliza dentro da área',
#       'IT': 'shot in goal gate inner upper center',
#       'RU': 'shot in goal gate inner upper center',
#       'ZH': 'shot in goal gate inner upper center',
#       'TR': 'shot in goal gate inner upper center',
#       'HU': 'shot in goal gate inner upper center',
#       'CS': 'shot in goal gate inner upper center',
#       'NL': 'shot in goal gate inner upper center'}},
#     'value': '1'},
#    {'name': 'shot_in_goal_gate_inner_upper_right',
#     'translations': {'name': {'EN': 'shot in goal gate inner upper right',
#       'FR': 'shot in goal gate inner upper right',
#       'DE': 'shot in goal gate inner upper right',
#       'ES': 'tiro a puerta a la parte superior derecha',
#       'PT': 'remate superior à direita da baliza dentro da área',
#       'IT': 'shot in goal gate inner upper right',
#       'RU': 'shot in goal gate inner upper right',
#       'ZH': 'shot in goal gate inner upper right',
#       'TR': 'shot in goal gate inner upper right',
#       'HU': 'shot in goal gate inner upper right',
#       'CS': 'shot in goal gate inner upper right',
#       'NL': 'shot in goal gate inner upper right'}},
#     'value': '1'},
#    {'name': 'shot_in_goal_gate_inner_lower_left',
#     'translations': {'name': {'EN': 'shot in goal gate inner lower left',
#       'FR': 'shot in goal gate inner lower left',
#       'DE': 'shot in goal gate inner lower left',
#       'ES': 'tiro a puerta a la parte inferior izquierda',
#       'PT': 'remate rasteiro à esquerda da baliza dentro da área',
#       'IT': 'shot in goal gate inner lower left',
#       'RU': 'shot in goal gate inner lower left',
#       'ZH': 'shot in goal gate inner lower left',
#       'TR': 'shot in goal gate inner lower left',
#       'HU': 'shot in goal gate inner lower left',
#       'CS': 'shot in goal gate inner lower left',
#       'NL': 'shot in goal gate inner lower left'}},
#     'value': '4'},
#    {'name': 'shot_in_goal_gate_inner_lower_center',
#     'translations': {'name': {'EN': 'shot in goal gate inner lower center',
#       'FR': 'shot in goal gate inner lower center',
#       'DE': 'shot in goal gate inner lower center',
#       'ES': 'tiro a puerta a la parte inferior central',
#       'PT': 'remate rasteiro ao centro da baliza dentro da área',
#       'IT': 'shot in goal gate inner lower center',
#       'RU': 'shot in goal gate inner lower center',
#       'ZH': 'shot in goal gate inner lower center',
#       'TR': 'shot in goal gate inner lower center',
#       'HU': 'shot in goal gate inner lower center',
#       'CS': 'shot in goal gate inner lower center',
#       'NL': 'shot in goal gate inner lower center'}},
#     'value': '1'},
#    {'name': 'shot_in_goal_gate_inner_lower_right',
#     'translations': {'name': {'EN': 'shot in goal gate inner lower right',
#       'FR': 'shot in goal gate inner lower right',
#       'DE': 'shot in goal gate inner lower right',
#       'ES': 'tiro a puerta a la parte inferior derecha',
#       'PT': 'remate rasteiro à direita da baliza dentro da área',
#       'IT': 'shot in goal gate inner lower right',
#       'RU': 'shot in goal gate inner lower right',
#       'ZH': 'shot in goal gate inner lower right',
#       'TR': 'shot in goal gate inner lower right',
#       'HU': 'shot in goal gate inner lower right',
#       'CS': 'shot in goal gate inner lower right',
#       'NL': 'shot in goal gate inner lower right'}},
#     'value': '2'},
#    {'name': 'shot_in_goal_gate_outer_lower_left',
#     'translations': {'name': {'EN': 'shot in goal gate outer lower left',
#       'FR': 'shot in goal gate outer lower left',
#       'DE': 'shot in goal gate outer lower left',
#       'ES': 'shot in goal gate outer lower left',
#       'PT': 'remate rasteiro à esquerda da baliza fora da área',
#       'IT': 'shot in goal gate outer lower left',
#       'RU': 'shot in goal gate outer lower left',
#       'ZH': 'shot in goal gate outer lower left',
#       'TR': 'shot in goal gate outer lower left',
#       'HU': 'shot in goal gate outer lower left',
#       'CS': 'shot in goal gate outer lower left',
#       'NL': 'shot in goal gate outer lower left'}},
#     'value': '0'},
#    {'name': 'shot_in_goal_gate_outer_upper_left',
#     'translations': {'name': {'EN': 'shot in goal gate outer upper left',
#       'FR': 'shot in goal gate outer upper left',
#       'DE': 'shot in goal gate outer upper left',
#       'ES': 'shot in goal gate outer upper left',
#       'PT': 'Remates à baliza superior esquerdo',
#       'IT': 'shot in goal gate outer upper left',
#       'RU': 'shot in goal gate outer upper left',
#       'ZH': 'shot in goal gate outer upper left',
#       'TR': 'shot in goal gate outer upper left',
#       'HU': 'shot in goal gate outer upper left',
#       'CS': 'shot in goal gate outer upper left',
#       'NL': 'shot in goal gate outer upper left'}},
#     'value': '2'},
#    {'name': 'shot_in_goal_gate_outer_upper_center',
#     'translations': {'name': {'EN': 'shot in goal gate outer upper center',
#       'FR': 'shot in goal gate outer upper center',
#       'DE': 'shot in goal gate outer upper center',
#       'ES': 'shot in goal gate outer upper center',
#       'PT': 'remate superior ao centro da baliza fora da área',
#       'IT': 'shot in goal gate outer upper center',
#       'RU': 'shot in goal gate outer upper center',
#       'ZH': 'shot in goal gate outer upper center',
#       'TR': 'shot in goal gate outer upper center',
#       'HU': 'shot in goal gate outer upper center',
#       'CS': 'shot in goal gate outer upper center',
#       'NL': 'shot in goal gate outer upper center'}},
#     'value': '3'},
#    {'name': 'shot_in_goal_gate_outer_upper_right',
#     'translations': {'name': {'EN': 'shot in goal gate outer upper right',
#       'FR': 'shot in goal gate outer upper right',
#       'DE': 'shot in goal gate outer upper right',
#       'ES': 'shot in goal gate outer upper right',
#       'PT': 'Remates à baliza superior direito',
#       'IT': 'shot in goal gate outer upper right',
#       'RU': 'shot in goal gate outer upper right',
#       'ZH': 'shot in goal gate outer upper right',
#       'TR': 'shot in goal gate outer upper right',
#       'HU': 'shot in goal gate outer upper right',
#       'CS': 'shot in goal gate outer upper right',
#       'NL': 'shot in goal gate outer upper right'}},
#     'value': '0'},
#    {'name': 'shot_in_goal_gate_outer_lower_right',
#     'translations': {'name': {'EN': 'shot in goal gate outer lower right',
#       'FR': 'shot in goal gate outer lower right',
#       'DE': 'shot in goal gate outer lower right',
#       'ES': 'shot in goal gate outer lower right',
#       'PT': 'remate rasteiro à direita da baliza fora da área',
#       'IT': 'shot in goal gate outer lower right',
#       'RU': 'shot in goal gate outer lower right',
#       'ZH': 'shot in goal gate outer lower right',
#       'TR': 'shot in goal gate outer lower right',
#       'HU': 'shot in goal gate outer lower right',
#       'CS': 'shot in goal gate outer lower right',
#       'NL': 'shot in goal gate outer lower right'}},
#     'value': '0'},
#    {'name': 'attempts_conceded',
#     'translations': {'name': {'EN': 'Attempts conceded',
#       'FR': 'Tentatives concédées',
#       'DE': 'Gegnerische Versuche',
#       'ES': 'Disparos concedidos',
#       'PT': 'Remates concedidos',
#       'IT': 'Tiri subiti',
#       'RU': 'Удары соперников',
#       'ZH': 'attempts conceded',
#       'TR': 'Attempts conceded',
#       'HU': 'Attempts conceded',
#       'CS': 'Attempts conceded',
#       'NL': 'Attempts conceded'}},
#     'value': '1'}],
#   'teamId': '47'}]

# %%
match_ids
# Out:
# ['2036161',
#  '2036162',
#  '2036163',
#  '2036164',
#  '2036167',
#  '2036165',
#  '2036166',
#  '2036170',
#  '2036169',
#  '2036168',
#  '2036171',
#  '2036172',
#  '2036176',
#  '2036173',
#  '2036174',
#  '2036177',
#  '2036178',
#  '2036175',
#  '2036182',
#  '2036179',
#  '2036180',
#  '2036184',
#  '2036183',
#  '2036181',
#  '2036185',
#  '2036186',
#  '2036187',
#  '2036188',
#  '2036192',
#  '2036191',
#  '2036189',
#  '2036190',
#  '2036194',
#  '2036193',
#  '2036196',
#  '2036195',
#  '2036198',
#  '2036197']
